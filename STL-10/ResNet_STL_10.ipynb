# %% [markdown]
# <a href="https://colab.research.google.com/github/dnrghks5583/Way-that-set-threshold-for-setting-PMD/blob/main/STL-10/ResNet_STL_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install extra-keras-datasets
from google.colab import drive
drive.mount('/content/gdrive')

path = '/content/gdrive/MyDrive/Colab Notebooks/ResNet_졸과/GP/stl10_binary'
# Out:
# Requirement already satisfied: extra-keras-datasets in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from extra-keras-datasets) (1.1.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from extra-keras-datasets) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from extra-keras-datasets) (0.22.2.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from extra-keras-datasets) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->extra-keras-datasets) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->extra-keras-datasets) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->extra-keras-datasets) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->extra-keras-datasets) (1.15.0)
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
"""
ResNet v1
[a] Deep Residual Learning for Image Recognition
https://arxiv.org/pdf/1512.03385.pdf
ResNet v2
[b] Identity Mappings in Deep Residual Networks
https://arxiv.org/pdf/1603.05027.pdf

https://github.com/dnrghks5583/Way-that-set-threshold-for-setting-PMD/blob/main/Caltech101/caltech101_resnet.ipynb
"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input
from tensorflow.keras.layers import Flatten, add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import numpy as np
import os
import math

# training parameters
batch_size = 32 # orig paper trained all networks with batch_size=128
epochs = 200
num_classes = 11
data_augmentation = True
learning_rate_variable = 3 # initial learning rate : 1e-learning rate, originally 3
checkpoint_directory = 'STL-10_saved_models_with_batch32_lr_e-' + str(learning_rate_variable) #not modified version saved at 'CALTECH-256_saved_models'
os.chdir(path)

# subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 9

# model version
# orig paper: version = 1 (ResNet v1), 
# improved ResNet: version = 2 (ResNet v2)
version = 1

# %%
from extra_keras_datasets import stl10
from keras.utils import np_utils

(x_train, y_train), (x_test, y_test) = stl10.load_data()

y_train = np_utils.to_categorical(y_train)
y_test  = np_utils.to_categorical(y_test )
# Out:
# INFO:root:Loading dataset = stl-10
# WARNING:root:Please cite the following paper when using or referencing this Extra Keras Dataset:
# WARNING:root:Coates, A., Ng, A., & Lee, H. (2011, June). An analysis of single-layer networks in unsupervised feature learning. In Proceedings of the fourteenth international conference on artificial intelligence and statistics (pp. 215-223).Retrieved from http://cs.stanford.edu/~acoates/papers/coatesleeng_aistats_2011.pdf

# %%
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# input image dimensions.
input_shape = x_train.shape[1:]

# normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# if subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('Model_Type : ' , model_type)
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# convert class vectors to binary class matrices.
#y_train = to_categorical(y_train, num_classes)
#y_test = to_categorical(y_test, num_classes)
# Out:
# Model_Type :  ResNet56v1
# x_train shape: (5000, 96, 96, 3)
# 5000 train samples
# 8000 test samples
# y_train shape: (5000, 11)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 1*(10**(-learning_rate_variable)) #originally 3
    if epoch > 180:
        lr *= 0.5*(10**(-learning_rate_variable)) #originally 3
    elif epoch > 160:
        lr *= 1*(10**(-learning_rate_variable)) #originally 3
    elif epoch > 120:
        lr *= 1*(10**(-learning_rate_variable+1)) #originally 2
    elif epoch > 80:
        lr *= 1*(10**(-learning_rate_variable+2)) #originally 1
    print('Learning rate: ', lr)
    return lr



def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=num_classes):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved
    (downsampled) by a convolutional layer with strides=2, while 
    the number of filters is doubled. Within each stage, 
    the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, in [a])')
    # start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            # first layer but not first stack
            if stack > 0 and res_block == 0:  
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            # first layer but not first stack
            if stack > 0 and res_block == 0:
                # linear projection residual shortcut
                # connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=num_classes):
    """ResNet Version 2 Model builder [b]
    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or 
    also known as bottleneck layer.
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, 
    the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, 
    while the number of filter maps is
    doubled. Within each stage, the layers have 
    the same number filters and the same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 110 in [b])')
    # start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU
    # on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                # first layer and first stage
                if res_block == 0:  
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                # first layer but not first stage
                if res_block == 0:
                    # downsample
                    strides = 2 

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection
                # to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])

        num_filters_in = num_filters_out

    # add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['acc'])
model.summary()

# enable this if pydot can be installed
# pip install pydot
#plot_model(model, to_file="%s.png" % model_type, show_shapes=True)
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 96, 96, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 96, 96, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 96, 96, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 96, 96, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 96, 96, 16)   2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 96, 96, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 96, 96, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 96, 96, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 96, 96, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 96, 96, 16)   0           activation[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 96, 96, 16)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 96, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 96, 96, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 96, 96, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 96, 96, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 96, 96, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 96, 96, 16)   0           activation_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 96, 96, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 96, 96, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 96, 96, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 96, 96, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 96, 96, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 96, 96, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 96, 96, 16)   0           activation_4[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 96, 96, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 96, 96, 16)   2320        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 96, 96, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 96, 96, 16)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 96, 96, 16)   2320        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 96, 96, 16)   64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 96, 96, 16)   0           activation_6[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 96, 96, 16)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 96, 96, 16)   2320        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 96, 96, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 96, 96, 16)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 96, 96, 16)   2320        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 96, 96, 16)   64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 96, 96, 16)   0           activation_8[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 96, 96, 16)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 96, 96, 16)   2320        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 96, 96, 16)   64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 96, 96, 16)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 96, 96, 16)   2320        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 96, 96, 16)   64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 96, 96, 16)   0           activation_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 96, 96, 16)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 96, 96, 16)   2320        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 96, 96, 16)   64          conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 96, 96, 16)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 96, 96, 16)   2320        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 96, 96, 16)   64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 96, 96, 16)   0           activation_12[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 96, 96, 16)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 96, 96, 16)   2320        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 96, 96, 16)   64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 96, 96, 16)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 96, 96, 16)   2320        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 96, 96, 16)   64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 96, 96, 16)   0           activation_14[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 96, 96, 16)   0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 96, 96, 16)   2320        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 96, 96, 16)   64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 96, 96, 16)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 96, 96, 16)   2320        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 96, 96, 16)   64          conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 96, 96, 16)   0           activation_16[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 96, 96, 16)   0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 48, 48, 32)   4640        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 48, 48, 32)   128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 48, 48, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 48, 48, 32)   9248        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 48, 48, 32)   544         activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 48, 48, 32)   128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 48, 48, 32)   0           conv2d_21[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 48, 48, 32)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 48, 48, 32)   9248        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 48, 48, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 48, 48, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 48, 48, 32)   9248        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 48, 48, 32)   128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 48, 48, 32)   0           activation_20[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 48, 48, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 48, 48, 32)   9248        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 48, 48, 32)   128         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 48, 48, 32)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 48, 48, 32)   9248        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 48, 48, 32)   128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 48, 48, 32)   0           activation_22[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 48, 48, 32)   0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 48, 48, 32)   9248        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 48, 48, 32)   128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 48, 48, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 48, 48, 32)   9248        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 48, 48, 32)   128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 48, 48, 32)   0           activation_24[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 48, 48, 32)   0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 48, 48, 32)   9248        activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 48, 48, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 48, 48, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 48, 48, 32)   9248        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 48, 48, 32)   128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 48, 48, 32)   0           activation_26[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 48, 48, 32)   0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 48, 48, 32)   9248        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 48, 48, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 48, 48, 32)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 48, 48, 32)   9248        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 48, 48, 32)   128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 48, 48, 32)   0           activation_28[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 48, 48, 32)   0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 48, 48, 32)   9248        activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 48, 48, 32)   128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 48, 48, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 48, 48, 32)   9248        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 48, 48, 32)   128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 48, 48, 32)   0           activation_30[0][0]
#                                                                  batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 48, 48, 32)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 48, 48, 32)   9248        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 48, 48, 32)   128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 48, 48, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 48, 48, 32)   9248        activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 48, 48, 32)   128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 48, 48, 32)   0           activation_32[0][0]
#                                                                  batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 48, 48, 32)   0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 48, 48, 32)   9248        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 48, 48, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 48, 48, 32)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 48, 48, 32)   9248        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 48, 48, 32)   128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 48, 48, 32)   0           activation_34[0][0]
#                                                                  batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 48, 48, 32)   0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 24, 24, 64)   18496       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 24, 24, 64)   256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 24, 24, 64)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 24, 24, 64)   36928       activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 24, 24, 64)   2112        activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 24, 24, 64)   256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 24, 24, 64)   0           conv2d_40[0][0]
#                                                                  batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 24, 24, 64)   0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 24, 24, 64)   36928       activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 24, 24, 64)   256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 24, 24, 64)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 24, 24, 64)   36928       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 24, 24, 64)   256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 24, 24, 64)   0           activation_38[0][0]
#                                                                  batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 24, 24, 64)   0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 24, 24, 64)   36928       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 24, 24, 64)   256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 24, 24, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 24, 24, 64)   36928       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 24, 24, 64)   256         conv2d_44[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 24, 24, 64)   0           activation_40[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 24, 24, 64)   0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 24, 24, 64)   36928       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 24, 24, 64)   256         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 24, 24, 64)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 24, 24, 64)   36928       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 24, 24, 64)   256         conv2d_46[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 24, 24, 64)   0           activation_42[0][0]
#                                                                  batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 24, 24, 64)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 24, 24, 64)   36928       activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 24, 24, 64)   256         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 24, 24, 64)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 24, 24, 64)   36928       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 24, 24, 64)   256         conv2d_48[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 24, 24, 64)   0           activation_44[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 24, 24, 64)   0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 24, 24, 64)   36928       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 24, 24, 64)   256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 24, 24, 64)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 24, 24, 64)   36928       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 24, 24, 64)   256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 24, 24, 64)   0           activation_46[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 24, 24, 64)   0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 24, 24, 64)   36928       activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 24, 24, 64)   256         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 24, 24, 64)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 24, 24, 64)   36928       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 24, 24, 64)   256         conv2d_52[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 24, 24, 64)   0           activation_48[0][0]
#                                                                  batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 24, 24, 64)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 24, 24, 64)   36928       activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 24, 24, 64)   256         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 24, 24, 64)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 24, 24, 64)   36928       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 24, 24, 64)   256         conv2d_54[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 24, 24, 64)   0           activation_50[0][0]
#                                                                  batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 24, 24, 64)   0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 24, 24, 64)   36928       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 24, 24, 64)   256         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 24, 24, 64)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 24, 24, 64)   36928       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 24, 24, 64)   256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 24, 24, 64)   0           activation_52[0][0]
#                                                                  batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 24, 24, 64)   0           add_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 3, 3, 64)     0           activation_54[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 576)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 11)           6347        flatten[0][0]
# ==================================================================================================
# Total params: 867,467
# Trainable params: 863,403
# Non-trainable params: 4,064
# __________________________________________________________________________________________________
# ResNet56v1

# %%
# prepare model model saving directory.

save_dir = os.path.join(os.getcwd(), checkpoint_directory)
model_name = 'STL-10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True) #initial True

# %%
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

#callbacks = [lr_reducer, lr_scheduler]
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # this will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False)
    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    steps_per_epoch =  math.ceil(len(x_train) / batch_size)
    # fit the model on the batches generated by datagen.flow().
    model.fit(x=datagen.flow(x_train, y_train, batch_size=batch_size),
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),
              steps_per_epoch=steps_per_epoch,
              callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/200
# Learning rate:  0.001
# 157/157 [==============================] - 65s 206ms/step - loss: 2.6232 - acc: 0.2818 - val_loss: 2.4464 - val_acc: 0.2564
#
# Epoch 00001: val_acc improved from -inf to 0.25638, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.001.h5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 2.1556 - acc: 0.3672 - val_loss: 2.5895 - val_acc: 0.3751
#
# Epoch 00002: val_acc improved from 0.25638 to 0.37512, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.002.h5
# Epoch 3/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 194ms/step - loss: 1.9458 - acc: 0.4532 - val_loss: 2.1123 - val_acc: 0.4658
#
# Epoch 00003: val_acc improved from 0.37512 to 0.46575, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.003.h5
# Epoch 4/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 193ms/step - loss: 1.8055 - acc: 0.5002 - val_loss: 1.8405 - val_acc: 0.4789
#
# Epoch 00004: val_acc improved from 0.46575 to 0.47888, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.004.h5
# Epoch 5/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 1.7390 - acc: 0.5182 - val_loss: 2.0483 - val_acc: 0.4364
#
# Epoch 00005: val_acc did not improve from 0.47888
# Epoch 6/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 163ms/step - loss: 1.6552 - acc: 0.5508 - val_loss: 1.7354 - val_acc: 0.5275
#
# Epoch 00006: val_acc improved from 0.47888 to 0.52750, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.006.h5
# Epoch 7/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 1.6313 - acc: 0.5586 - val_loss: 3.3951 - val_acc: 0.3296
#
# Epoch 00007: val_acc did not improve from 0.52750
# Epoch 8/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 163ms/step - loss: 1.5422 - acc: 0.5982 - val_loss: 1.8087 - val_acc: 0.5117
#
# Epoch 00008: val_acc did not improve from 0.52750
# Epoch 9/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 1.5284 - acc: 0.6002 - val_loss: 1.6698 - val_acc: 0.5604
#
# Epoch 00009: val_acc improved from 0.52750 to 0.56037, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.009.h5
# Epoch 10/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 1.4768 - acc: 0.6134 - val_loss: 1.9592 - val_acc: 0.5113
#
# Epoch 00010: val_acc did not improve from 0.56037
# Epoch 11/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 1.4235 - acc: 0.6306 - val_loss: 2.0650 - val_acc: 0.4803
#
# Epoch 00011: val_acc did not improve from 0.56037
# Epoch 12/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 1.3845 - acc: 0.6390 - val_loss: 1.9546 - val_acc: 0.5245
#
# Epoch 00012: val_acc did not improve from 0.56037
# Epoch 13/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 194ms/step - loss: 1.3370 - acc: 0.6512 - val_loss: 1.7181 - val_acc: 0.5278
#
# Epoch 00013: val_acc did not improve from 0.56037
# Epoch 14/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 163ms/step - loss: 1.3443 - acc: 0.6574 - val_loss: 1.5639 - val_acc: 0.5888
#
# Epoch 00014: val_acc improved from 0.56037 to 0.58875, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.014.h5
# Epoch 15/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 194ms/step - loss: 1.2942 - acc: 0.6704 - val_loss: 2.0732 - val_acc: 0.5245
#
# Epoch 00015: val_acc did not improve from 0.58875
# Epoch 16/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 163ms/step - loss: 1.2753 - acc: 0.6758 - val_loss: 2.1302 - val_acc: 0.4647
#
# Epoch 00016: val_acc did not improve from 0.58875
# Epoch 17/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 193ms/step - loss: 1.2368 - acc: 0.6944 - val_loss: 1.4042 - val_acc: 0.6503
#
# Epoch 00017: val_acc improved from 0.58875 to 0.65025, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.017.h5
# Epoch 18/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 1.2275 - acc: 0.6894 - val_loss: 1.5158 - val_acc: 0.6105
#
# Epoch 00018: val_acc did not improve from 0.65025
# Epoch 19/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 1.1904 - acc: 0.7012 - val_loss: 1.3243 - val_acc: 0.6654
#
# Epoch 00019: val_acc improved from 0.65025 to 0.66537, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.019.h5
# Epoch 20/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 165ms/step - loss: 1.1636 - acc: 0.6998 - val_loss: 1.5513 - val_acc: 0.6161
#
# Epoch 00020: val_acc did not improve from 0.66537
# Epoch 21/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 165ms/step - loss: 1.1841 - acc: 0.7032 - val_loss: 1.7995 - val_acc: 0.5661
#
# Epoch 00021: val_acc did not improve from 0.66537
# Epoch 22/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 1.1381 - acc: 0.7196 - val_loss: 1.9956 - val_acc: 0.5085
#
# Epoch 00022: val_acc did not improve from 0.66537
# Epoch 23/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 1.1253 - acc: 0.7214 - val_loss: 1.2735 - val_acc: 0.6802
#
# Epoch 00023: val_acc improved from 0.66537 to 0.68025, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.023.h5
# Epoch 24/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 1.0926 - acc: 0.7318 - val_loss: 1.8505 - val_acc: 0.5441
#
# Epoch 00024: val_acc did not improve from 0.68025
# Epoch 25/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 1.0765 - acc: 0.7394 - val_loss: 1.3259 - val_acc: 0.6729
#
# Epoch 00025: val_acc did not improve from 0.68025
# Epoch 26/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 1.0701 - acc: 0.7326 - val_loss: 1.7429 - val_acc: 0.5621
#
# Epoch 00026: val_acc did not improve from 0.68025
# Epoch 27/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 163ms/step - loss: 1.0382 - acc: 0.7504 - val_loss: 1.9964 - val_acc: 0.5523
#
# Epoch 00027: val_acc did not improve from 0.68025
# Epoch 28/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 1.0369 - acc: 0.7418 - val_loss: 1.4876 - val_acc: 0.6346
#
# Epoch 00028: val_acc did not improve from 0.68025
# Epoch 29/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 1.0051 - acc: 0.7550 - val_loss: 1.3419 - val_acc: 0.6639
#
# Epoch 00029: val_acc did not improve from 0.68025
# Epoch 30/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 166ms/step - loss: 0.9961 - acc: 0.7642 - val_loss: 1.4784 - val_acc: 0.6242
#
# Epoch 00030: val_acc did not improve from 0.68025
# Epoch 31/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.9739 - acc: 0.7652 - val_loss: 1.5659 - val_acc: 0.6183
#
# Epoch 00031: val_acc did not improve from 0.68025
# Epoch 32/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.9741 - acc: 0.7652 - val_loss: 1.5091 - val_acc: 0.6457
#
# Epoch 00032: val_acc did not improve from 0.68025
# Epoch 33/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.9407 - acc: 0.7782 - val_loss: 1.4989 - val_acc: 0.6541
#
# Epoch 00033: val_acc did not improve from 0.68025
# Epoch 34/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 0.9489 - acc: 0.7794 - val_loss: 1.8479 - val_acc: 0.6005
#
# Epoch 00034: val_acc did not improve from 0.68025
# Epoch 35/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.8990 - acc: 0.7904 - val_loss: 1.2628 - val_acc: 0.6877
#
# Epoch 00035: val_acc improved from 0.68025 to 0.68775, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.035.h5
# Epoch 36/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 0.9133 - acc: 0.7860 - val_loss: 1.2785 - val_acc: 0.6815
#
# Epoch 00036: val_acc did not improve from 0.68775
# Epoch 37/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 194ms/step - loss: 0.8730 - acc: 0.7982 - val_loss: 1.3935 - val_acc: 0.6624
#
# Epoch 00037: val_acc did not improve from 0.68775
# Epoch 38/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.8975 - acc: 0.7936 - val_loss: 1.4145 - val_acc: 0.6469
#
# Epoch 00038: val_acc did not improve from 0.68775
# Epoch 39/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 196ms/step - loss: 0.8536 - acc: 0.8064 - val_loss: 1.3166 - val_acc: 0.6825
#
# Epoch 00039: val_acc did not improve from 0.68775
# Epoch 40/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 165ms/step - loss: 0.8569 - acc: 0.8106 - val_loss: 1.8022 - val_acc: 0.5715
#
# Epoch 00040: val_acc did not improve from 0.68775
# Epoch 41/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 0.8517 - acc: 0.8076 - val_loss: 1.4948 - val_acc: 0.6421
#
# Epoch 00041: val_acc did not improve from 0.68775
# Epoch 42/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.8328 - acc: 0.8160 - val_loss: 1.5641 - val_acc: 0.6239
#
# Epoch 00042: val_acc did not improve from 0.68775
# Epoch 43/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.8037 - acc: 0.8238 - val_loss: 1.4182 - val_acc: 0.6716
#
# Epoch 00043: val_acc did not improve from 0.68775
# Epoch 44/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 0.8292 - acc: 0.8178 - val_loss: 1.5436 - val_acc: 0.6640
#
# Epoch 00044: val_acc did not improve from 0.68775
# Epoch 45/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.7925 - acc: 0.8258 - val_loss: 1.3814 - val_acc: 0.6906
#
# Epoch 00045: val_acc improved from 0.68775 to 0.69063, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.045.h5
# Epoch 46/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.7869 - acc: 0.8326 - val_loss: 1.7110 - val_acc: 0.6133
#
# Epoch 00046: val_acc did not improve from 0.69063
# Epoch 47/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.7396 - acc: 0.8540 - val_loss: 1.3837 - val_acc: 0.6914
#
# Epoch 00047: val_acc improved from 0.69063 to 0.69138, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.047.h5
# Epoch 48/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 0.7821 - acc: 0.8290 - val_loss: 2.4581 - val_acc: 0.5465
#
# Epoch 00048: val_acc did not improve from 0.69138
# Epoch 49/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 0.7381 - acc: 0.8446 - val_loss: 1.4409 - val_acc: 0.6793
#
# Epoch 00049: val_acc did not improve from 0.69138
# Epoch 50/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 194ms/step - loss: 0.7645 - acc: 0.8366 - val_loss: 1.4955 - val_acc: 0.6494
#
# Epoch 00050: val_acc did not improve from 0.69138
# Epoch 51/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 0.7703 - acc: 0.8372 - val_loss: 1.1634 - val_acc: 0.7228
#
# Epoch 00051: val_acc improved from 0.69138 to 0.72275, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.051.h5
# Epoch 52/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.7249 - acc: 0.8500 - val_loss: 1.2545 - val_acc: 0.7138
#
# Epoch 00052: val_acc did not improve from 0.72275
# Epoch 53/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.7183 - acc: 0.8530 - val_loss: 2.1332 - val_acc: 0.5821
#
# Epoch 00053: val_acc did not improve from 0.72275
# Epoch 54/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.6984 - acc: 0.8610 - val_loss: 1.5038 - val_acc: 0.6614
#
# Epoch 00054: val_acc did not improve from 0.72275
# Epoch 55/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.7120 - acc: 0.8612 - val_loss: 2.4313 - val_acc: 0.5620
#
# Epoch 00055: val_acc did not improve from 0.72275
# Epoch 56/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.6839 - acc: 0.8662 - val_loss: 1.5752 - val_acc: 0.6625
#
# Epoch 00056: val_acc did not improve from 0.72275
# Epoch 57/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.7178 - acc: 0.8592 - val_loss: 1.3629 - val_acc: 0.6990
#
# Epoch 00057: val_acc did not improve from 0.72275
# Epoch 58/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.6913 - acc: 0.8608 - val_loss: 1.4258 - val_acc: 0.6761
#
# Epoch 00058: val_acc did not improve from 0.72275
# Epoch 59/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.6855 - acc: 0.8650 - val_loss: 1.1452 - val_acc: 0.7574
#
# Epoch 00059: val_acc improved from 0.72275 to 0.75738, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.059.h5
# Epoch 60/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 194ms/step - loss: 0.6543 - acc: 0.8820 - val_loss: 1.4549 - val_acc: 0.6870
#
# Epoch 00060: val_acc did not improve from 0.75738
# Epoch 61/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 195ms/step - loss: 0.6424 - acc: 0.8808 - val_loss: 1.3654 - val_acc: 0.7030
#
# Epoch 00061: val_acc did not improve from 0.75738
# Epoch 62/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.6715 - acc: 0.8706 - val_loss: 1.3307 - val_acc: 0.7036
#
# Epoch 00062: val_acc did not improve from 0.75738
# Epoch 63/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.6778 - acc: 0.8726 - val_loss: 1.8717 - val_acc: 0.6305
#
# Epoch 00063: val_acc did not improve from 0.75738
# Epoch 64/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.6584 - acc: 0.8798 - val_loss: 1.5713 - val_acc: 0.6637
#
# Epoch 00064: val_acc did not improve from 0.75738
# Epoch 65/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.6304 - acc: 0.8912 - val_loss: 1.1818 - val_acc: 0.7451
#
# Epoch 00065: val_acc did not improve from 0.75738
# Epoch 66/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.6104 - acc: 0.8936 - val_loss: 1.2879 - val_acc: 0.6986
#
# Epoch 00066: val_acc did not improve from 0.75738
# Epoch 67/200
# Learning rate:  0.001
# 157/157 [==============================] - 31s 194ms/step - loss: 0.6078 - acc: 0.8926 - val_loss: 1.9745 - val_acc: 0.6335
#
# Epoch 00067: val_acc did not improve from 0.75738
# Epoch 68/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.6238 - acc: 0.8940 - val_loss: 1.6054 - val_acc: 0.6867
#
# Epoch 00068: val_acc did not improve from 0.75738
# Epoch 69/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.6368 - acc: 0.8854 - val_loss: 1.6684 - val_acc: 0.6591
#
# Epoch 00069: val_acc did not improve from 0.75738
# Epoch 70/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.6133 - acc: 0.8940 - val_loss: 1.6943 - val_acc: 0.6848
#
# Epoch 00070: val_acc did not improve from 0.75738
# Epoch 71/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 193ms/step - loss: 0.6370 - acc: 0.8882 - val_loss: 1.2095 - val_acc: 0.7274
#
# Epoch 00071: val_acc did not improve from 0.75738
# Epoch 72/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.6158 - acc: 0.8954 - val_loss: 1.4491 - val_acc: 0.6783
#
# Epoch 00072: val_acc did not improve from 0.75738
# Epoch 73/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.6055 - acc: 0.8972 - val_loss: 1.3786 - val_acc: 0.7082
#
# Epoch 00073: val_acc did not improve from 0.75738
# Epoch 74/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.5768 - acc: 0.9070 - val_loss: 1.3477 - val_acc: 0.7231
#
# Epoch 00074: val_acc did not improve from 0.75738
# Epoch 75/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 193ms/step - loss: 0.5928 - acc: 0.9042 - val_loss: 1.6529 - val_acc: 0.6973
#
# Epoch 00075: val_acc did not improve from 0.75738
# Epoch 76/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.5756 - acc: 0.9118 - val_loss: 1.4258 - val_acc: 0.7020
#
# Epoch 00076: val_acc did not improve from 0.75738
# Epoch 77/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.5780 - acc: 0.9058 - val_loss: 1.8451 - val_acc: 0.6373
#
# Epoch 00077: val_acc did not improve from 0.75738
# Epoch 78/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 193ms/step - loss: 0.5919 - acc: 0.9044 - val_loss: 1.4040 - val_acc: 0.7070
#
# Epoch 00078: val_acc did not improve from 0.75738
# Epoch 79/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 193ms/step - loss: 0.5565 - acc: 0.9166 - val_loss: 1.3459 - val_acc: 0.7193
#
# Epoch 00079: val_acc did not improve from 0.75738
# Epoch 80/200
# Learning rate:  0.001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.5772 - acc: 0.9070 - val_loss: 2.2306 - val_acc: 0.6190
#
# Epoch 00080: val_acc did not improve from 0.75738
# Epoch 81/200
# Learning rate:  0.001
# 157/157 [==============================] - 30s 193ms/step - loss: 0.5673 - acc: 0.9100 - val_loss: 1.5325 - val_acc: 0.6955
#
# Epoch 00081: val_acc did not improve from 0.75738
# Epoch 82/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.4689 - acc: 0.9504 - val_loss: 0.9927 - val_acc: 0.7986
#
# Epoch 00082: val_acc improved from 0.75738 to 0.79862, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.082.h5
# Epoch 83/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.4247 - acc: 0.9658 - val_loss: 1.0196 - val_acc: 0.7962
#
# Epoch 00083: val_acc did not improve from 0.79862
# Epoch 84/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.4057 - acc: 0.9746 - val_loss: 0.9967 - val_acc: 0.8024
#
# Epoch 00084: val_acc improved from 0.79862 to 0.80238, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.084.h5
# Epoch 85/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.3917 - acc: 0.9794 - val_loss: 0.9980 - val_acc: 0.8029
#
# Epoch 00085: val_acc improved from 0.80238 to 0.80287, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.085.h5
# Epoch 86/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 193ms/step - loss: 0.3845 - acc: 0.9800 - val_loss: 1.0059 - val_acc: 0.8062
#
# Epoch 00086: val_acc improved from 0.80287 to 0.80625, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.086.h5
# Epoch 87/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.3789 - acc: 0.9814 - val_loss: 0.9910 - val_acc: 0.8074
#
# Epoch 00087: val_acc improved from 0.80625 to 0.80738, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.087.h5
# Epoch 88/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 162ms/step - loss: 0.3690 - acc: 0.9858 - val_loss: 1.0121 - val_acc: 0.8045
#
# Epoch 00088: val_acc did not improve from 0.80738
# Epoch 89/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 193ms/step - loss: 0.3679 - acc: 0.9836 - val_loss: 0.9959 - val_acc: 0.8080
#
# Epoch 00089: val_acc improved from 0.80738 to 0.80800, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.089.h5
# Epoch 90/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.3661 - acc: 0.9840 - val_loss: 0.9843 - val_acc: 0.8108
#
# Epoch 00090: val_acc improved from 0.80800 to 0.81075, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.090.h5
# Epoch 91/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.3616 - acc: 0.9856 - val_loss: 1.0094 - val_acc: 0.8045
#
# Epoch 00091: val_acc did not improve from 0.81075
# Epoch 92/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.3541 - acc: 0.9892 - val_loss: 0.9961 - val_acc: 0.8089
#
# Epoch 00092: val_acc did not improve from 0.81075
# Epoch 93/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.3545 - acc: 0.9868 - val_loss: 1.0337 - val_acc: 0.7985
#
# Epoch 00093: val_acc did not improve from 0.81075
# Epoch 94/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 193ms/step - loss: 0.3522 - acc: 0.9840 - val_loss: 1.0079 - val_acc: 0.8061
#
# Epoch 00094: val_acc did not improve from 0.81075
# Epoch 95/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 193ms/step - loss: 0.3442 - acc: 0.9896 - val_loss: 1.0131 - val_acc: 0.8070
#
# Epoch 00095: val_acc did not improve from 0.81075
# Epoch 96/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 193ms/step - loss: 0.3405 - acc: 0.9894 - val_loss: 1.0110 - val_acc: 0.8071
#
# Epoch 00096: val_acc did not improve from 0.81075
# Epoch 97/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.3367 - acc: 0.9870 - val_loss: 1.0143 - val_acc: 0.8054
#
# Epoch 00097: val_acc did not improve from 0.81075
# Epoch 98/200
# Learning rate:  0.0001
# 157/157 [==============================] - 31s 195ms/step - loss: 0.3302 - acc: 0.9916 - val_loss: 1.0020 - val_acc: 0.8135
#
# Epoch 00098: val_acc improved from 0.81075 to 0.81350, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.098.h5
# Epoch 99/200
# Learning rate:  0.0001
# 157/157 [==============================] - 31s 195ms/step - loss: 0.3319 - acc: 0.9900 - val_loss: 1.0543 - val_acc: 0.8024
#
# Epoch 00099: val_acc did not improve from 0.81350
# Epoch 100/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.3242 - acc: 0.9924 - val_loss: 1.0271 - val_acc: 0.8086
#
# Epoch 00100: val_acc did not improve from 0.81350
# Epoch 101/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.3189 - acc: 0.9930 - val_loss: 1.0116 - val_acc: 0.8096
#
# Epoch 00101: val_acc did not improve from 0.81350
# Epoch 102/200
# Learning rate:  0.0001
# 157/157 [==============================] - 31s 195ms/step - loss: 0.3223 - acc: 0.9898 - val_loss: 1.0364 - val_acc: 0.8036
#
# Epoch 00102: val_acc did not improve from 0.81350
# Epoch 103/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.3159 - acc: 0.9926 - val_loss: 1.0036 - val_acc: 0.8136
#
# Epoch 00103: val_acc improved from 0.81350 to 0.81362, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.103.h5
# Epoch 104/200
# Learning rate:  0.0001
# 157/157 [==============================] - 31s 194ms/step - loss: 0.3135 - acc: 0.9936 - val_loss: 1.0264 - val_acc: 0.8098
#
# Epoch 00104: val_acc did not improve from 0.81362
# Epoch 105/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.3115 - acc: 0.9924 - val_loss: 1.0361 - val_acc: 0.8105
#
# Epoch 00105: val_acc did not improve from 0.81362
# Epoch 106/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 192ms/step - loss: 0.3123 - acc: 0.9918 - val_loss: 1.0145 - val_acc: 0.8074
#
# Epoch 00106: val_acc did not improve from 0.81362
# Epoch 107/200
# Learning rate:  0.0001
# 157/157 [==============================] - 25s 163ms/step - loss: 0.3103 - acc: 0.9922 - val_loss: 1.0148 - val_acc: 0.8115
#
# Epoch 00107: val_acc did not improve from 0.81362
# Epoch 108/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.3040 - acc: 0.9920 - val_loss: 1.0294 - val_acc: 0.8095
#
# Epoch 00108: val_acc did not improve from 0.81362
# Epoch 109/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.2984 - acc: 0.9948 - val_loss: 1.0531 - val_acc: 0.8031
#
# Epoch 00109: val_acc did not improve from 0.81362
# Epoch 110/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 193ms/step - loss: 0.3006 - acc: 0.9926 - val_loss: 1.0250 - val_acc: 0.8106
#
# Epoch 00110: val_acc did not improve from 0.81362
# Epoch 111/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.2970 - acc: 0.9920 - val_loss: 1.0153 - val_acc: 0.8114
#
# Epoch 00111: val_acc did not improve from 0.81362
# Epoch 112/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.2935 - acc: 0.9940 - val_loss: 1.0521 - val_acc: 0.8048
#
# Epoch 00112: val_acc did not improve from 0.81362
# Epoch 113/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.2924 - acc: 0.9932 - val_loss: 1.0362 - val_acc: 0.8081
#
# Epoch 00113: val_acc did not improve from 0.81362
# Epoch 114/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.2856 - acc: 0.9958 - val_loss: 1.0446 - val_acc: 0.8066
#
# Epoch 00114: val_acc did not improve from 0.81362
# Epoch 115/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.2881 - acc: 0.9924 - val_loss: 1.0637 - val_acc: 0.7999
#
# Epoch 00115: val_acc did not improve from 0.81362
# Epoch 116/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 163ms/step - loss: 0.2863 - acc: 0.9938 - val_loss: 1.0807 - val_acc: 0.7991
#
# Epoch 00116: val_acc did not improve from 0.81362
# Epoch 117/200
# Learning rate:  0.0001
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2804 - acc: 0.9948 - val_loss: 1.0079 - val_acc: 0.8136
#
# Epoch 00117: val_acc did not improve from 0.81362
# Epoch 118/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.2827 - acc: 0.9934 - val_loss: 1.0174 - val_acc: 0.8121
#
# Epoch 00118: val_acc did not improve from 0.81362
# Epoch 119/200
# Learning rate:  0.0001
# 157/157 [==============================] - 26s 164ms/step - loss: 0.2780 - acc: 0.9940 - val_loss: 1.0546 - val_acc: 0.8090
#
# Epoch 00119: val_acc did not improve from 0.81362
# Epoch 120/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.2808 - acc: 0.9914 - val_loss: 1.1072 - val_acc: 0.8019
#
# Epoch 00120: val_acc did not improve from 0.81362
# Epoch 121/200
# Learning rate:  0.0001
# 157/157 [==============================] - 30s 194ms/step - loss: 0.2735 - acc: 0.9948 - val_loss: 1.0316 - val_acc: 0.8116
#
# Epoch 00121: val_acc did not improve from 0.81362
# Epoch 122/200
# Learning rate:  1e-05
# 157/157 [==============================] - 30s 194ms/step - loss: 0.2711 - acc: 0.9954 - val_loss: 1.0124 - val_acc: 0.8144
#
# Epoch 00122: val_acc improved from 0.81362 to 0.81437, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.122.h5
# Epoch 123/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2673 - acc: 0.9966 - val_loss: 1.0116 - val_acc: 0.8146
#
# Epoch 00123: val_acc improved from 0.81437 to 0.81463, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.123.h5
# Epoch 124/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2645 - acc: 0.9984 - val_loss: 1.0074 - val_acc: 0.8159
#
# Epoch 00124: val_acc improved from 0.81463 to 0.81587, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.124.h5
# Epoch 125/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 166ms/step - loss: 0.2701 - acc: 0.9954 - val_loss: 1.0074 - val_acc: 0.8161
#
# Epoch 00125: val_acc improved from 0.81587 to 0.81612, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.125.h5
# Epoch 126/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2668 - acc: 0.9966 - val_loss: 1.0045 - val_acc: 0.8167
#
# Epoch 00126: val_acc improved from 0.81612 to 0.81675, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.126.h5
# Epoch 127/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 197ms/step - loss: 0.2654 - acc: 0.9970 - val_loss: 1.0004 - val_acc: 0.8184
#
# Epoch 00127: val_acc improved from 0.81675 to 0.81837, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.127.h5
# Epoch 128/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 166ms/step - loss: 0.2662 - acc: 0.9954 - val_loss: 1.0091 - val_acc: 0.8165
#
# Epoch 00128: val_acc did not improve from 0.81837
# Epoch 129/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 166ms/step - loss: 0.2636 - acc: 0.9970 - val_loss: 0.9950 - val_acc: 0.8186
#
# Epoch 00129: val_acc improved from 0.81837 to 0.81862, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.129.h5
# Epoch 130/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2648 - acc: 0.9968 - val_loss: 1.0012 - val_acc: 0.8169
#
# Epoch 00130: val_acc did not improve from 0.81862
# Epoch 131/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2648 - acc: 0.9960 - val_loss: 0.9987 - val_acc: 0.8179
#
# Epoch 00131: val_acc did not improve from 0.81862
# Epoch 132/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2628 - acc: 0.9972 - val_loss: 0.9984 - val_acc: 0.8165
#
# Epoch 00132: val_acc did not improve from 0.81862
# Epoch 133/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2641 - acc: 0.9962 - val_loss: 1.0006 - val_acc: 0.8184
#
# Epoch 00133: val_acc did not improve from 0.81862
# Epoch 134/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2601 - acc: 0.9982 - val_loss: 1.0007 - val_acc: 0.8189
#
# Epoch 00134: val_acc improved from 0.81862 to 0.81888, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.134.h5
# Epoch 135/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 197ms/step - loss: 0.2630 - acc: 0.9972 - val_loss: 1.0054 - val_acc: 0.8174
#
# Epoch 00135: val_acc did not improve from 0.81888
# Epoch 136/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2590 - acc: 0.9984 - val_loss: 1.0027 - val_acc: 0.8181
#
# Epoch 00136: val_acc did not improve from 0.81888
# Epoch 137/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 164ms/step - loss: 0.2608 - acc: 0.9976 - val_loss: 1.0060 - val_acc: 0.8191
#
# Epoch 00137: val_acc improved from 0.81888 to 0.81912, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.137.h5
# Epoch 138/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2602 - acc: 0.9980 - val_loss: 1.0063 - val_acc: 0.8191
#
# Epoch 00138: val_acc did not improve from 0.81912
# Epoch 139/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2598 - acc: 0.9976 - val_loss: 1.0041 - val_acc: 0.8188
#
# Epoch 00139: val_acc did not improve from 0.81912
# Epoch 140/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 194ms/step - loss: 0.2589 - acc: 0.9984 - val_loss: 1.0040 - val_acc: 0.8195
#
# Epoch 00140: val_acc improved from 0.81912 to 0.81950, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.140.h5
# Epoch 141/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2578 - acc: 0.9982 - val_loss: 1.0045 - val_acc: 0.8191
#
# Epoch 00141: val_acc did not improve from 0.81950
# Epoch 142/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2587 - acc: 0.9978 - val_loss: 1.0079 - val_acc: 0.8169
#
# Epoch 00142: val_acc did not improve from 0.81950
# Epoch 143/200
# Learning rate:  1e-05
# 157/157 [==============================] - 30s 194ms/step - loss: 0.2580 - acc: 0.9978 - val_loss: 1.0080 - val_acc: 0.8174
#
# Epoch 00143: val_acc did not improve from 0.81950
# Epoch 144/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 163ms/step - loss: 0.2569 - acc: 0.9982 - val_loss: 1.0087 - val_acc: 0.8191
#
# Epoch 00144: val_acc did not improve from 0.81950
# Epoch 145/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2580 - acc: 0.9982 - val_loss: 1.0067 - val_acc: 0.8196
#
# Epoch 00145: val_acc improved from 0.81950 to 0.81963, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.145.h5
# Epoch 146/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2572 - acc: 0.9978 - val_loss: 1.0051 - val_acc: 0.8202
#
# Epoch 00146: val_acc improved from 0.81963 to 0.82025, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.146.h5
# Epoch 147/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2580 - acc: 0.9970 - val_loss: 1.0077 - val_acc: 0.8196
#
# Epoch 00147: val_acc did not improve from 0.82025
# Epoch 148/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 164ms/step - loss: 0.2565 - acc: 0.9988 - val_loss: 1.0031 - val_acc: 0.8183
#
# Epoch 00148: val_acc did not improve from 0.82025
# Epoch 149/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 164ms/step - loss: 0.2556 - acc: 0.9982 - val_loss: 1.0096 - val_acc: 0.8199
#
# Epoch 00149: val_acc did not improve from 0.82025
# Epoch 150/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2558 - acc: 0.9976 - val_loss: 1.0130 - val_acc: 0.8186
#
# Epoch 00150: val_acc did not improve from 0.82025
# Epoch 151/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2558 - acc: 0.9974 - val_loss: 1.0138 - val_acc: 0.8176
#
# Epoch 00151: val_acc did not improve from 0.82025
# Epoch 152/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2533 - acc: 0.9988 - val_loss: 1.0129 - val_acc: 0.8195
#
# Epoch 00152: val_acc did not improve from 0.82025
# Epoch 153/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2548 - acc: 0.9976 - val_loss: 1.0121 - val_acc: 0.8192
#
# Epoch 00153: val_acc did not improve from 0.82025
# Epoch 154/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 166ms/step - loss: 0.2534 - acc: 0.9992 - val_loss: 1.0135 - val_acc: 0.8191
#
# Epoch 00154: val_acc did not improve from 0.82025
# Epoch 155/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2531 - acc: 0.9984 - val_loss: 1.0092 - val_acc: 0.8215
#
# Epoch 00155: val_acc improved from 0.82025 to 0.82150, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.155.h5
# Epoch 156/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2529 - acc: 0.9984 - val_loss: 1.0120 - val_acc: 0.8189
#
# Epoch 00156: val_acc did not improve from 0.82150
# Epoch 157/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 164ms/step - loss: 0.2519 - acc: 0.9988 - val_loss: 1.0101 - val_acc: 0.8213
#
# Epoch 00157: val_acc did not improve from 0.82150
# Epoch 158/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2514 - acc: 0.9990 - val_loss: 1.0085 - val_acc: 0.8198
#
# Epoch 00158: val_acc did not improve from 0.82150
# Epoch 159/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2527 - acc: 0.9978 - val_loss: 1.0111 - val_acc: 0.8204
#
# Epoch 00159: val_acc did not improve from 0.82150
# Epoch 160/200
# Learning rate:  1e-05
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2539 - acc: 0.9986 - val_loss: 1.0125 - val_acc: 0.8201
#
# Epoch 00160: val_acc did not improve from 0.82150
# Epoch 161/200
# Learning rate:  1e-05
# 157/157 [==============================] - 26s 164ms/step - loss: 0.2518 - acc: 0.9980 - val_loss: 1.0162 - val_acc: 0.8204
#
# Epoch 00161: val_acc did not improve from 0.82150
# Epoch 162/200
# Learning rate:  1e-06
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2521 - acc: 0.9984 - val_loss: 1.0163 - val_acc: 0.8205
#
# Epoch 00162: val_acc did not improve from 0.82150
# Epoch 163/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2524 - acc: 0.9980 - val_loss: 1.0155 - val_acc: 0.8209
#
# Epoch 00163: val_acc did not improve from 0.82150
# Epoch 164/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2519 - acc: 0.9986 - val_loss: 1.0151 - val_acc: 0.8211
#
# Epoch 00164: val_acc did not improve from 0.82150
# Epoch 165/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2501 - acc: 0.9994 - val_loss: 1.0153 - val_acc: 0.8210
#
# Epoch 00165: val_acc did not improve from 0.82150
# Epoch 166/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2512 - acc: 0.9986 - val_loss: 1.0119 - val_acc: 0.8215
#
# Epoch 00166: val_acc did not improve from 0.82150
# Epoch 167/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2518 - acc: 0.9982 - val_loss: 1.0122 - val_acc: 0.8219
#
# Epoch 00167: val_acc improved from 0.82150 to 0.82187, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.167.h5
# Epoch 168/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 197ms/step - loss: 0.2513 - acc: 0.9988 - val_loss: 1.0118 - val_acc: 0.8214
#
# Epoch 00168: val_acc did not improve from 0.82187
# Epoch 169/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2519 - acc: 0.9982 - val_loss: 1.0097 - val_acc: 0.8217
#
# Epoch 00169: val_acc did not improve from 0.82187
# Epoch 170/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2533 - acc: 0.9982 - val_loss: 1.0113 - val_acc: 0.8214
#
# Epoch 00170: val_acc did not improve from 0.82187
# Epoch 171/200
# Learning rate:  1e-06
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2506 - acc: 0.9982 - val_loss: 1.0116 - val_acc: 0.8217
#
# Epoch 00171: val_acc did not improve from 0.82187
# Epoch 172/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 195ms/step - loss: 0.2497 - acc: 0.9990 - val_loss: 1.0120 - val_acc: 0.8221
#
# Epoch 00172: val_acc improved from 0.82187 to 0.82213, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.172.h5
# Epoch 173/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 197ms/step - loss: 0.2518 - acc: 0.9984 - val_loss: 1.0113 - val_acc: 0.8217
#
# Epoch 00173: val_acc did not improve from 0.82213
# Epoch 174/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2521 - acc: 0.9986 - val_loss: 1.0111 - val_acc: 0.8216
#
# Epoch 00174: val_acc did not improve from 0.82213
# Epoch 175/200
# Learning rate:  1e-06
# 157/157 [==============================] - 26s 167ms/step - loss: 0.2511 - acc: 0.9984 - val_loss: 1.0110 - val_acc: 0.8207
#
# Epoch 00175: val_acc did not improve from 0.82213
# Epoch 176/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2526 - acc: 0.9984 - val_loss: 1.0103 - val_acc: 0.8217
#
# Epoch 00176: val_acc did not improve from 0.82213
# Epoch 177/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 197ms/step - loss: 0.2512 - acc: 0.9988 - val_loss: 1.0118 - val_acc: 0.8215
#
# Epoch 00177: val_acc did not improve from 0.82213
# Epoch 178/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 197ms/step - loss: 0.2524 - acc: 0.9974 - val_loss: 1.0111 - val_acc: 0.8207
#
# Epoch 00178: val_acc did not improve from 0.82213
# Epoch 179/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 197ms/step - loss: 0.2509 - acc: 0.9970 - val_loss: 1.0094 - val_acc: 0.8215
#
# Epoch 00179: val_acc did not improve from 0.82213
# Epoch 180/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2514 - acc: 0.9978 - val_loss: 1.0114 - val_acc: 0.8214
#
# Epoch 00180: val_acc did not improve from 0.82213
# Epoch 181/200
# Learning rate:  1e-06
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2514 - acc: 0.9976 - val_loss: 1.0099 - val_acc: 0.8211
#
# Epoch 00181: val_acc did not improve from 0.82213
# Epoch 182/200
# Learning rate:  5e-07
# 157/157 [==============================] - 26s 166ms/step - loss: 0.2501 - acc: 0.9984 - val_loss: 1.0103 - val_acc: 0.8206
#
# Epoch 00182: val_acc did not improve from 0.82213
# Epoch 183/200
# Learning rate:  5e-07
# 157/157 [==============================] - 26s 166ms/step - loss: 0.2514 - acc: 0.9988 - val_loss: 1.0116 - val_acc: 0.8214
#
# Epoch 00183: val_acc did not improve from 0.82213
# Epoch 184/200
# Learning rate:  5e-07
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2504 - acc: 0.9984 - val_loss: 1.0106 - val_acc: 0.8216
#
# Epoch 00184: val_acc did not improve from 0.82213
# Epoch 185/200
# Learning rate:  5e-07
# 157/157 [==============================] - 26s 166ms/step - loss: 0.2514 - acc: 0.9982 - val_loss: 1.0097 - val_acc: 0.8211
#
# Epoch 00185: val_acc did not improve from 0.82213
# Epoch 186/200
# Learning rate:  5e-07
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2507 - acc: 0.9990 - val_loss: 1.0096 - val_acc: 0.8204
#
# Epoch 00186: val_acc did not improve from 0.82213
# Epoch 187/200
# Learning rate:  5e-07
# 157/157 [==============================] - 26s 166ms/step - loss: 0.2519 - acc: 0.9974 - val_loss: 1.0103 - val_acc: 0.8211
#
# Epoch 00187: val_acc did not improve from 0.82213
# Epoch 188/200
# Learning rate:  5e-07
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2505 - acc: 0.9992 - val_loss: 1.0097 - val_acc: 0.8216
#
# Epoch 00188: val_acc did not improve from 0.82213
# Epoch 189/200
# Learning rate:  5e-07
# 157/157 [==============================] - 26s 166ms/step - loss: 0.2497 - acc: 0.9982 - val_loss: 1.0090 - val_acc: 0.8214
#
# Epoch 00189: val_acc did not improve from 0.82213
# Epoch 190/200
# Learning rate:  5e-07
# 157/157 [==============================] - 26s 165ms/step - loss: 0.2506 - acc: 0.9984 - val_loss: 1.0102 - val_acc: 0.8210
#
# Epoch 00190: val_acc did not improve from 0.82213
# Epoch 191/200
# Learning rate:  5e-07
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2509 - acc: 0.9982 - val_loss: 1.0101 - val_acc: 0.8210
#
# Epoch 00191: val_acc did not improve from 0.82213
# Epoch 192/200
# Learning rate:  5e-07
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2503 - acc: 0.9986 - val_loss: 1.0097 - val_acc: 0.8213
#
# Epoch 00192: val_acc did not improve from 0.82213
# Epoch 193/200
# Learning rate:  5e-07
# 157/157 [==============================] - 31s 197ms/step - loss: 0.2515 - acc: 0.9982 - val_loss: 1.0114 - val_acc: 0.8211
#
# Epoch 00193: val_acc did not improve from 0.82213
# Epoch 194/200
# Learning rate:  5e-07
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2509 - acc: 0.9986 - val_loss: 1.0113 - val_acc: 0.8221
#
# Epoch 00194: val_acc did not improve from 0.82213
# Epoch 195/200
# Learning rate:  5e-07
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2510 - acc: 0.9982 - val_loss: 1.0102 - val_acc: 0.8217
#
# Epoch 00195: val_acc did not improve from 0.82213
# Epoch 196/200
# Learning rate:  5e-07
# 157/157 [==============================] - 31s 197ms/step - loss: 0.2511 - acc: 0.9986 - val_loss: 1.0106 - val_acc: 0.8224
#
# Epoch 00196: val_acc improved from 0.82213 to 0.82237, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/stl10_binary/STL-10_saved_models_with_batch32_lr_e-3/STL-10_ResNet56v1_model.196.h5
# Epoch 197/200
# Learning rate:  5e-07
# 157/157 [==============================] - 31s 197ms/step - loss: 0.2501 - acc: 0.9986 - val_loss: 1.0105 - val_acc: 0.8217
#
# Epoch 00197: val_acc did not improve from 0.82237
# Epoch 198/200
# Learning rate:  5e-07
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2504 - acc: 0.9986 - val_loss: 1.0108 - val_acc: 0.8215
#
# Epoch 00198: val_acc did not improve from 0.82237
# Epoch 199/200
# Learning rate:  5e-07
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2528 - acc: 0.9974 - val_loss: 1.0095 - val_acc: 0.8213
#
# Epoch 00199: val_acc did not improve from 0.82237
# Epoch 200/200
# Learning rate:  5e-07
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2510 - acc: 0.9976 - val_loss: 1.0097 - val_acc: 0.8213
#
# Epoch 00200: val_acc did not improve from 0.82237

# %%
# score trained model
scores = model.evaluate(x_test,
                        y_test,
                        batch_size=batch_size,
                        verbose=0)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Test loss: 1.009676218032837
# Test accuracy: 0.8212500214576721
