# %% [markdown]
# <a href="https://colab.research.google.com/github/dnrghks5583/Way-that-set-threshold-for-setting-PMD/blob/main/CALTECH-101/ResNet_CALTECH_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')

path = '/content/gdrive/MyDrive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164'
# Out:
# Mounted at /content/gdrive

# %%
"""
ResNet v1
[a] Deep Residual Learning for Image Recognition
https://arxiv.org/pdf/1512.03385.pdf
ResNet v2
[b] Identity Mappings in Deep Residual Networks
https://arxiv.org/pdf/1603.05027.pdf

https://github.com/dnrghks5583/Way-that-set-threshold-for-setting-PMD/blob/main/Caltech101/caltech101_resnet.ipynb
"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input
from tensorflow.keras.layers import Flatten, add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import numpy as np
import os
import math

# training parameters
batch_size = 128 # orig paper trained all networks with batch_size=128
epochs = 100
num_classes = 102
data_augmentation = True
learning_rate_variable = 3 # initial learning rate : 1e-learning rate, originally 3
checkpoint_directory = 'CALTECH-101_saved_models_with_lr_e-' + str(learning_rate_variable) #not modified version saved at 'CALTECH-256_saved_models'

# subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 9

# model version
# orig paper: version = 1 (ResNet v1), 
# improved ResNet: version = 2 (ResNet v2)
version = 1

# %%
import gzip
import pickle

os.chdir(path)

with gzip.open('caltech101_x_trainData.pickle', 'rb') as f:
    x_train = pickle.load(f)
    
with gzip.open('caltech101_x_testData.pickle', 'rb') as f:
    x_test = pickle.load(f)
    
with gzip.open('caltech101_y_trainData.pickle', 'rb') as f:
    y_train = pickle.load(f)
    
with gzip.open('caltech101_y_testData.pickle', 'rb') as f:
    y_test = pickle.load(f)

# %%
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# input image dimensions.
input_shape = x_train.shape[1:]

# normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# if subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('Model_Type : ' , model_type)
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# convert class vectors to binary class matrices.
#y_train = to_categorical(y_train, num_classes)
#y_test = to_categorical(y_test, num_classes)
# Out:
# Model_Type :  ResNet56v1
# x_train shape: (7316, 164, 164, 3)
# 7316 train samples
# 1829 test samples
# y_train shape: (7316, 102)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 1*(10**(-learning_rate_variable)) #originally 3
    if epoch > 180:
        lr *= 0.5*(10**(-learning_rate_variable)) #originally 3
    elif epoch > 160:
        lr *= 1*(10**(-learning_rate_variable)) #originally 3
    elif epoch > 120:
        lr *= 1*(10**(-learning_rate_variable+1)) #originally 2
    elif epoch > 80:
        lr *= 1*(10**(-learning_rate_variable+2)) #originally 1
    print('Learning rate: ', lr)
    return lr



def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=num_classes):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved
    (downsampled) by a convolutional layer with strides=2, while 
    the number of filters is doubled. Within each stage, 
    the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, in [a])')
    # start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            # first layer but not first stack
            if stack > 0 and res_block == 0:  
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            # first layer but not first stack
            if stack > 0 and res_block == 0:
                # linear projection residual shortcut
                # connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=num_classes):
    """ResNet Version 2 Model builder [b]
    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or 
    also known as bottleneck layer.
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, 
    the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, 
    while the number of filter maps is
    doubled. Within each stage, the layers have 
    the same number filters and the same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 110 in [b])')
    # start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU
    # on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                # first layer and first stage
                if res_block == 0:  
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                # first layer but not first stage
                if res_block == 0:
                    # downsample
                    strides = 2 

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection
                # to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])

        num_filters_in = num_filters_out

    # add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['acc'])
model.summary()

# enable this if pydot can be installed
# pip install pydot
#plot_model(model, to_file="%s.png" % model_type, show_shapes=True)
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 164, 164, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 164, 164, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 164, 164, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 164, 164, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 164, 164, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 164, 164, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 164, 164, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 164, 164, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 164, 164, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 164, 164, 16) 0           activation[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 164, 164, 16) 0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 164, 164, 16) 2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 164, 164, 16) 64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 164, 164, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 164, 164, 16) 2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 164, 164, 16) 64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 164, 164, 16) 0           activation_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 164, 164, 16) 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 164, 164, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 164, 164, 16) 64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 164, 164, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 164, 164, 16) 2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 164, 164, 16) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 164, 164, 16) 0           activation_4[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 164, 164, 16) 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 164, 164, 16) 2320        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 164, 164, 16) 64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 164, 164, 16) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 164, 164, 16) 2320        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 164, 164, 16) 64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 164, 164, 16) 0           activation_6[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 164, 164, 16) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 164, 164, 16) 2320        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 164, 164, 16) 64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 164, 164, 16) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 164, 164, 16) 2320        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 164, 164, 16) 64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 164, 164, 16) 0           activation_8[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 164, 164, 16) 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 164, 164, 16) 2320        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 164, 164, 16) 64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 164, 164, 16) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 164, 164, 16) 2320        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 164, 164, 16) 64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 164, 164, 16) 0           activation_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 164, 164, 16) 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 164, 164, 16) 2320        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 164, 164, 16) 64          conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 164, 164, 16) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 164, 164, 16) 2320        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 164, 164, 16) 64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 164, 164, 16) 0           activation_12[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 164, 164, 16) 0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 164, 164, 16) 2320        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 164, 164, 16) 64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 164, 164, 16) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 164, 164, 16) 2320        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 164, 164, 16) 64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 164, 164, 16) 0           activation_14[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 164, 164, 16) 0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 164, 164, 16) 2320        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 164, 164, 16) 64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 164, 164, 16) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 164, 164, 16) 2320        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 164, 164, 16) 64          conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 164, 164, 16) 0           activation_16[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 164, 164, 16) 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 82, 82, 32)   4640        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 82, 82, 32)   128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 82, 82, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 82, 82, 32)   9248        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 82, 82, 32)   544         activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 82, 82, 32)   128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 82, 82, 32)   0           conv2d_21[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 82, 82, 32)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 82, 82, 32)   9248        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 82, 82, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 82, 82, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 82, 82, 32)   9248        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 82, 82, 32)   128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 82, 82, 32)   0           activation_20[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 82, 82, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 82, 82, 32)   9248        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 82, 82, 32)   128         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 82, 82, 32)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 82, 82, 32)   9248        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 82, 82, 32)   128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 82, 82, 32)   0           activation_22[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 82, 82, 32)   0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 82, 82, 32)   9248        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 82, 82, 32)   128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 82, 82, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 82, 82, 32)   9248        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 82, 82, 32)   128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 82, 82, 32)   0           activation_24[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 82, 82, 32)   0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 82, 82, 32)   9248        activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 82, 82, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 82, 82, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 82, 82, 32)   9248        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 82, 82, 32)   128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 82, 82, 32)   0           activation_26[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 82, 82, 32)   0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 82, 82, 32)   9248        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 82, 82, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 82, 82, 32)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 82, 82, 32)   9248        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 82, 82, 32)   128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 82, 82, 32)   0           activation_28[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 82, 82, 32)   0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 82, 82, 32)   9248        activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 82, 82, 32)   128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 82, 82, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 82, 82, 32)   9248        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 82, 82, 32)   128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 82, 82, 32)   0           activation_30[0][0]
#                                                                  batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 82, 82, 32)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 82, 82, 32)   9248        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 82, 82, 32)   128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 82, 82, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 82, 82, 32)   9248        activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 82, 82, 32)   128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 82, 82, 32)   0           activation_32[0][0]
#                                                                  batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 82, 82, 32)   0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 82, 82, 32)   9248        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 82, 82, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 82, 82, 32)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 82, 82, 32)   9248        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 82, 82, 32)   128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 82, 82, 32)   0           activation_34[0][0]
#                                                                  batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 82, 82, 32)   0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 41, 41, 64)   18496       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 41, 41, 64)   256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 41, 41, 64)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 41, 41, 64)   36928       activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 41, 41, 64)   2112        activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 41, 41, 64)   256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 41, 41, 64)   0           conv2d_40[0][0]
#                                                                  batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 41, 41, 64)   0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 41, 41, 64)   36928       activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 41, 41, 64)   256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 41, 41, 64)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 41, 41, 64)   36928       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 41, 41, 64)   256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 41, 41, 64)   0           activation_38[0][0]
#                                                                  batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 41, 41, 64)   0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 41, 41, 64)   36928       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 41, 41, 64)   256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 41, 41, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 41, 41, 64)   36928       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 41, 41, 64)   256         conv2d_44[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 41, 41, 64)   0           activation_40[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 41, 41, 64)   0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 41, 41, 64)   36928       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 41, 41, 64)   256         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 41, 41, 64)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 41, 41, 64)   36928       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 41, 41, 64)   256         conv2d_46[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 41, 41, 64)   0           activation_42[0][0]
#                                                                  batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 41, 41, 64)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 41, 41, 64)   36928       activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 41, 41, 64)   256         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 41, 41, 64)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 41, 41, 64)   36928       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 41, 41, 64)   256         conv2d_48[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 41, 41, 64)   0           activation_44[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 41, 41, 64)   0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 41, 41, 64)   36928       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 41, 41, 64)   256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 41, 41, 64)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 41, 41, 64)   36928       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 41, 41, 64)   256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 41, 41, 64)   0           activation_46[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 41, 41, 64)   0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 41, 41, 64)   36928       activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 41, 41, 64)   256         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 41, 41, 64)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 41, 41, 64)   36928       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 41, 41, 64)   256         conv2d_52[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 41, 41, 64)   0           activation_48[0][0]
#                                                                  batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 41, 41, 64)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 41, 41, 64)   36928       activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 41, 41, 64)   256         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 41, 41, 64)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 41, 41, 64)   36928       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 41, 41, 64)   256         conv2d_54[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 41, 41, 64)   0           activation_50[0][0]
#                                                                  batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 41, 41, 64)   0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 41, 41, 64)   36928       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 41, 41, 64)   256         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 41, 41, 64)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 41, 41, 64)   36928       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 41, 41, 64)   256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 41, 41, 64)   0           activation_52[0][0]
#                                                                  batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 41, 41, 64)   0           add_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 5, 5, 64)     0           activation_54[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1600)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 102)          163302      flatten[0][0]
# ==================================================================================================
# Total params: 1,024,422
# Trainable params: 1,020,358
# Non-trainable params: 4,064
# __________________________________________________________________________________________________
# ResNet56v1

# %%
# prepare model model saving directory.

save_dir = os.path.join(os.getcwd(), checkpoint_directory)
model_name = 'CALTECH-101_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True) #initial True

# %%
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

#callbacks = [lr_reducer, lr_scheduler]
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # this will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False)
    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    steps_per_epoch =  math.ceil(len(x_train) / batch_size)
    # fit the model on the batches generated by datagen.flow().
    model.fit(x=datagen.flow(x_train, y_train, batch_size=batch_size),
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),
              steps_per_epoch=steps_per_epoch,
              callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/100
# Learning rate:  0.001
# 58/58 [==============================] - 80s 1s/step - loss: 5.2915 - acc: 0.1971 - val_loss: 6.4033 - val_acc: 0.0776
#
# Epoch 00001: val_acc improved from -inf to 0.07764, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.001.h5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 3.7087 - acc: 0.3166 - val_loss: 4.4686 - val_acc: 0.1864
#
# Epoch 00002: val_acc improved from 0.07764 to 0.18644, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.002.h5
# Epoch 3/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 3.2480 - acc: 0.3767 - val_loss: 4.1573 - val_acc: 0.2160
#
# Epoch 00003: val_acc improved from 0.18644 to 0.21597, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.003.h5
# Epoch 4/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 2.8612 - acc: 0.4482 - val_loss: 3.5314 - val_acc: 0.3155
#
# Epoch 00004: val_acc improved from 0.21597 to 0.31547, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.004.h5
# Epoch 5/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 2.6372 - acc: 0.4850 - val_loss: 3.0211 - val_acc: 0.4024
#
# Epoch 00005: val_acc improved from 0.31547 to 0.40241, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.005.h5
# Epoch 6/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 2.4269 - acc: 0.5148 - val_loss: 2.7425 - val_acc: 0.4598
#
# Epoch 00006: val_acc improved from 0.40241 to 0.45981, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.006.h5
# Epoch 7/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 2.2439 - acc: 0.5574 - val_loss: 2.4437 - val_acc: 0.5030
#
# Epoch 00007: val_acc improved from 0.45981 to 0.50301, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.007.h5
# Epoch 8/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 2.0400 - acc: 0.5929 - val_loss: 2.5888 - val_acc: 0.4833
#
# Epoch 00008: val_acc did not improve from 0.50301
# Epoch 9/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.9662 - acc: 0.6069 - val_loss: 2.2624 - val_acc: 0.5714
#
# Epoch 00009: val_acc improved from 0.50301 to 0.57135, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.009.h5
# Epoch 10/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 1.8615 - acc: 0.6285 - val_loss: 2.1138 - val_acc: 0.5883
#
# Epoch 00010: val_acc improved from 0.57135 to 0.58830, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.010.h5
# Epoch 11/100
# Learning rate:  0.001
# 58/58 [==============================] - 65s 1s/step - loss: 1.7575 - acc: 0.6453 - val_loss: 2.1296 - val_acc: 0.6113
#
# Epoch 00011: val_acc improved from 0.58830 to 0.61126, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.011.h5
# Epoch 12/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.7107 - acc: 0.6550 - val_loss: 2.2112 - val_acc: 0.6003
#
# Epoch 00012: val_acc did not improve from 0.61126
# Epoch 13/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.6070 - acc: 0.6771 - val_loss: 2.1386 - val_acc: 0.6129
#
# Epoch 00013: val_acc improved from 0.61126 to 0.61290, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.013.h5
# Epoch 14/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.5416 - acc: 0.6914 - val_loss: 2.0504 - val_acc: 0.6206
#
# Epoch 00014: val_acc improved from 0.61290 to 0.62056, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.014.h5
# Epoch 15/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.5260 - acc: 0.6931 - val_loss: 2.3141 - val_acc: 0.5861
#
# Epoch 00015: val_acc did not improve from 0.62056
# Epoch 16/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 1.4487 - acc: 0.7134 - val_loss: 1.9454 - val_acc: 0.6495
#
# Epoch 00016: val_acc improved from 0.62056 to 0.64954, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.016.h5
# Epoch 17/100
# Learning rate:  0.001
# 58/58 [==============================] - 65s 1s/step - loss: 1.3906 - acc: 0.7233 - val_loss: 2.1115 - val_acc: 0.6255
#
# Epoch 00017: val_acc did not improve from 0.64954
# Epoch 18/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.3312 - acc: 0.7344 - val_loss: 1.7364 - val_acc: 0.6796
#
# Epoch 00018: val_acc improved from 0.64954 to 0.67961, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.018.h5
# Epoch 19/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.2893 - acc: 0.7462 - val_loss: 1.9496 - val_acc: 0.6539
#
# Epoch 00019: val_acc did not improve from 0.67961
# Epoch 20/100
# Learning rate:  0.001
# 58/58 [==============================] - 65s 1s/step - loss: 1.2133 - acc: 0.7546 - val_loss: 1.8412 - val_acc: 0.6687
#
# Epoch 00020: val_acc did not improve from 0.67961
# Epoch 21/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.2517 - acc: 0.7466 - val_loss: 1.9197 - val_acc: 0.6709
#
# Epoch 00021: val_acc did not improve from 0.67961
# Epoch 22/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.1550 - acc: 0.7710 - val_loss: 2.0930 - val_acc: 0.6413
#
# Epoch 00022: val_acc did not improve from 0.67961
# Epoch 23/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.1206 - acc: 0.7752 - val_loss: 1.7550 - val_acc: 0.6829
#
# Epoch 00023: val_acc improved from 0.67961 to 0.68289, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.023.h5
# Epoch 24/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.0962 - acc: 0.7791 - val_loss: 2.0097 - val_acc: 0.6479
#
# Epoch 00024: val_acc did not improve from 0.68289
# Epoch 25/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 1.0974 - acc: 0.7786 - val_loss: 1.8626 - val_acc: 0.6698
#
# Epoch 00025: val_acc did not improve from 0.68289
# Epoch 26/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.0656 - acc: 0.7911 - val_loss: 1.9442 - val_acc: 0.6523
#
# Epoch 00026: val_acc did not improve from 0.68289
# Epoch 27/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 1.0146 - acc: 0.7998 - val_loss: 1.7510 - val_acc: 0.6873
#
# Epoch 00027: val_acc improved from 0.68289 to 0.68726, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.027.h5
# Epoch 28/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 1.0061 - acc: 0.8051 - val_loss: 1.9414 - val_acc: 0.6594
#
# Epoch 00028: val_acc did not improve from 0.68726
# Epoch 29/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 0.9353 - acc: 0.8196 - val_loss: 1.9517 - val_acc: 0.6490
#
# Epoch 00029: val_acc did not improve from 0.68726
# Epoch 30/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.9834 - acc: 0.8013 - val_loss: 1.7848 - val_acc: 0.6823
#
# Epoch 00030: val_acc did not improve from 0.68726
# Epoch 31/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.8925 - acc: 0.8345 - val_loss: 2.0038 - val_acc: 0.6703
#
# Epoch 00031: val_acc did not improve from 0.68726
# Epoch 32/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.8817 - acc: 0.8361 - val_loss: 1.6574 - val_acc: 0.7037
#
# Epoch 00032: val_acc improved from 0.68726 to 0.70366, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.032.h5
# Epoch 33/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.8470 - acc: 0.8421 - val_loss: 1.9807 - val_acc: 0.6687
#
# Epoch 00033: val_acc did not improve from 0.70366
# Epoch 34/100
# Learning rate:  0.001
# 58/58 [==============================] - 65s 1s/step - loss: 0.8164 - acc: 0.8502 - val_loss: 1.8783 - val_acc: 0.6878
#
# Epoch 00034: val_acc did not improve from 0.70366
# Epoch 35/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.8317 - acc: 0.8403 - val_loss: 1.7670 - val_acc: 0.7048
#
# Epoch 00035: val_acc improved from 0.70366 to 0.70476, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.035.h5
# Epoch 36/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 0.7676 - acc: 0.8570 - val_loss: 1.8047 - val_acc: 0.6927
#
# Epoch 00036: val_acc did not improve from 0.70476
# Epoch 37/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.8331 - acc: 0.8386 - val_loss: 1.8161 - val_acc: 0.6802
#
# Epoch 00037: val_acc did not improve from 0.70476
# Epoch 38/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.7188 - acc: 0.8703 - val_loss: 2.3319 - val_acc: 0.6534
#
# Epoch 00038: val_acc did not improve from 0.70476
# Epoch 39/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.7928 - acc: 0.8520 - val_loss: 1.9403 - val_acc: 0.6955
#
# Epoch 00039: val_acc did not improve from 0.70476
# Epoch 40/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 0.7086 - acc: 0.8741 - val_loss: 1.8512 - val_acc: 0.7064
#
# Epoch 00040: val_acc improved from 0.70476 to 0.70640, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.040.h5
# Epoch 41/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.7097 - acc: 0.8760 - val_loss: 1.8570 - val_acc: 0.6971
#
# Epoch 00041: val_acc did not improve from 0.70640
# Epoch 42/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.6941 - acc: 0.8755 - val_loss: 2.0734 - val_acc: 0.6763
#
# Epoch 00042: val_acc did not improve from 0.70640
# Epoch 43/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.6860 - acc: 0.8737 - val_loss: 1.9732 - val_acc: 0.6916
#
# Epoch 00043: val_acc did not improve from 0.70640
# Epoch 44/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.6652 - acc: 0.8816 - val_loss: 2.0847 - val_acc: 0.6763
#
# Epoch 00044: val_acc did not improve from 0.70640
# Epoch 45/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.6530 - acc: 0.8841 - val_loss: 1.9772 - val_acc: 0.6987
#
# Epoch 00045: val_acc did not improve from 0.70640
# Epoch 46/100
# Learning rate:  0.001
# 58/58 [==============================] - 65s 1s/step - loss: 0.6417 - acc: 0.8881 - val_loss: 1.8125 - val_acc: 0.7004
#
# Epoch 00046: val_acc did not improve from 0.70640
# Epoch 47/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 0.6142 - acc: 0.8963 - val_loss: 1.8350 - val_acc: 0.7020
#
# Epoch 00047: val_acc did not improve from 0.70640
# Epoch 48/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.6176 - acc: 0.8930 - val_loss: 2.1351 - val_acc: 0.6610
#
# Epoch 00048: val_acc did not improve from 0.70640
# Epoch 49/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.6503 - acc: 0.8840 - val_loss: 1.9615 - val_acc: 0.7075
#
# Epoch 00049: val_acc improved from 0.70640 to 0.70749, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.049.h5
# Epoch 50/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 0.5731 - acc: 0.9080 - val_loss: 1.8214 - val_acc: 0.7124
#
# Epoch 00050: val_acc improved from 0.70749 to 0.71241, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.050.h5
# Epoch 51/100
# Learning rate:  0.001
# 58/58 [==============================] - 65s 1s/step - loss: 0.5860 - acc: 0.8997 - val_loss: 1.8554 - val_acc: 0.6938
#
# Epoch 00051: val_acc did not improve from 0.71241
# Epoch 52/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.5675 - acc: 0.9054 - val_loss: 1.9512 - val_acc: 0.6933
#
# Epoch 00052: val_acc did not improve from 0.71241
# Epoch 53/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.5882 - acc: 0.8980 - val_loss: 2.0362 - val_acc: 0.6856
#
# Epoch 00053: val_acc did not improve from 0.71241
# Epoch 54/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.5704 - acc: 0.9023 - val_loss: 1.9158 - val_acc: 0.6976
#
# Epoch 00054: val_acc did not improve from 0.71241
# Epoch 55/100
# Learning rate:  0.001
# 58/58 [==============================] - 65s 1s/step - loss: 0.5786 - acc: 0.9038 - val_loss: 1.9229 - val_acc: 0.6955
#
# Epoch 00055: val_acc did not improve from 0.71241
# Epoch 56/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.5251 - acc: 0.9136 - val_loss: 2.0640 - val_acc: 0.6687
#
# Epoch 00056: val_acc did not improve from 0.71241
# Epoch 57/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.5566 - acc: 0.9050 - val_loss: 2.0027 - val_acc: 0.7080
#
# Epoch 00057: val_acc did not improve from 0.71241
# Epoch 58/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.5291 - acc: 0.9148 - val_loss: 2.1498 - val_acc: 0.6785
#
# Epoch 00058: val_acc did not improve from 0.71241
# Epoch 59/100
# Learning rate:  0.001
# 58/58 [==============================] - 65s 1s/step - loss: 0.5314 - acc: 0.9133 - val_loss: 1.9657 - val_acc: 0.7102
#
# Epoch 00059: val_acc did not improve from 0.71241
# Epoch 60/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.5114 - acc: 0.9163 - val_loss: 1.9627 - val_acc: 0.7015
#
# Epoch 00060: val_acc did not improve from 0.71241
# Epoch 61/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 0.5075 - acc: 0.9177 - val_loss: 2.0428 - val_acc: 0.7135
#
# Epoch 00061: val_acc improved from 0.71241 to 0.71350, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.061.h5
# Epoch 62/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4939 - acc: 0.9232 - val_loss: 1.9990 - val_acc: 0.6703
#
# Epoch 00062: val_acc did not improve from 0.71350
# Epoch 63/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4765 - acc: 0.9247 - val_loss: 2.4338 - val_acc: 0.6714
#
# Epoch 00063: val_acc did not improve from 0.71350
# Epoch 64/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.5105 - acc: 0.9165 - val_loss: 2.0238 - val_acc: 0.7037
#
# Epoch 00064: val_acc did not improve from 0.71350
# Epoch 65/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.5066 - acc: 0.9121 - val_loss: 2.4670 - val_acc: 0.6654
#
# Epoch 00065: val_acc did not improve from 0.71350
# Epoch 66/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4493 - acc: 0.9332 - val_loss: 2.0681 - val_acc: 0.7004
#
# Epoch 00066: val_acc did not improve from 0.71350
# Epoch 67/100
# Learning rate:  0.001
# 58/58 [==============================] - 65s 1s/step - loss: 0.4592 - acc: 0.9285 - val_loss: 1.9930 - val_acc: 0.6993
#
# Epoch 00067: val_acc did not improve from 0.71350
# Epoch 68/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4561 - acc: 0.9302 - val_loss: 1.9505 - val_acc: 0.7141
#
# Epoch 00068: val_acc improved from 0.71350 to 0.71405, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.068.h5
# Epoch 69/100
# Learning rate:  0.001
# 58/58 [==============================] - 65s 1s/step - loss: 0.4227 - acc: 0.9358 - val_loss: 2.1352 - val_acc: 0.6878
#
# Epoch 00069: val_acc did not improve from 0.71405
# Epoch 70/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4321 - acc: 0.9358 - val_loss: 1.8229 - val_acc: 0.7168
#
# Epoch 00070: val_acc improved from 0.71405 to 0.71679, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.070.h5
# Epoch 71/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4556 - acc: 0.9269 - val_loss: 2.0898 - val_acc: 0.6802
#
# Epoch 00071: val_acc did not improve from 0.71679
# Epoch 72/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4172 - acc: 0.9393 - val_loss: 2.0870 - val_acc: 0.6982
#
# Epoch 00072: val_acc did not improve from 0.71679
# Epoch 73/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4459 - acc: 0.9303 - val_loss: 2.1285 - val_acc: 0.6966
#
# Epoch 00073: val_acc did not improve from 0.71679
# Epoch 74/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.3989 - acc: 0.9472 - val_loss: 2.0068 - val_acc: 0.7141
#
# Epoch 00074: val_acc did not improve from 0.71679
# Epoch 75/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4427 - acc: 0.9297 - val_loss: 2.3266 - val_acc: 0.6878
#
# Epoch 00075: val_acc did not improve from 0.71679
# Epoch 76/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4220 - acc: 0.9356 - val_loss: 1.9347 - val_acc: 0.7141
#
# Epoch 00076: val_acc did not improve from 0.71679
# Epoch 77/100
# Learning rate:  0.001
# 58/58 [==============================] - 67s 1s/step - loss: 0.4259 - acc: 0.9370 - val_loss: 2.0768 - val_acc: 0.7075
#
# Epoch 00077: val_acc did not improve from 0.71679
# Epoch 78/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4482 - acc: 0.9281 - val_loss: 2.2928 - val_acc: 0.7009
#
# Epoch 00078: val_acc did not improve from 0.71679
# Epoch 79/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4162 - acc: 0.9349 - val_loss: 2.1125 - val_acc: 0.7053
#
# Epoch 00079: val_acc did not improve from 0.71679
# Epoch 80/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4391 - acc: 0.9308 - val_loss: 1.9625 - val_acc: 0.7069
#
# Epoch 00080: val_acc did not improve from 0.71679
# Epoch 81/100
# Learning rate:  0.001
# 58/58 [==============================] - 66s 1s/step - loss: 0.4025 - acc: 0.9400 - val_loss: 2.3438 - val_acc: 0.6812
#
# Epoch 00081: val_acc did not improve from 0.71679
# Epoch 82/100
# Learning rate:  0.0001
# 58/58 [==============================] - 66s 1s/step - loss: 0.3392 - acc: 0.9608 - val_loss: 1.8398 - val_acc: 0.7425
#
# Epoch 00082: val_acc improved from 0.71679 to 0.74248, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.082.h5
# Epoch 83/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2946 - acc: 0.9761 - val_loss: 1.7742 - val_acc: 0.7463
#
# Epoch 00083: val_acc improved from 0.74248 to 0.74631, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.083.h5
# Epoch 84/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2868 - acc: 0.9792 - val_loss: 1.7511 - val_acc: 0.7474
#
# Epoch 00084: val_acc improved from 0.74631 to 0.74740, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.084.h5
# Epoch 85/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2786 - acc: 0.9809 - val_loss: 1.7935 - val_acc: 0.7469
#
# Epoch 00085: val_acc did not improve from 0.74740
# Epoch 86/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2803 - acc: 0.9807 - val_loss: 1.7699 - val_acc: 0.7479
#
# Epoch 00086: val_acc improved from 0.74740 to 0.74795, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.086.h5
# Epoch 87/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2725 - acc: 0.9844 - val_loss: 1.7738 - val_acc: 0.7507
#
# Epoch 00087: val_acc improved from 0.74795 to 0.75068, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.087.h5
# Epoch 88/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2734 - acc: 0.9803 - val_loss: 1.7779 - val_acc: 0.7485
#
# Epoch 00088: val_acc did not improve from 0.75068
# Epoch 89/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2681 - acc: 0.9832 - val_loss: 1.7838 - val_acc: 0.7523
#
# Epoch 00089: val_acc improved from 0.75068 to 0.75232, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.089.h5
# Epoch 90/100
# Learning rate:  0.0001
# 58/58 [==============================] - 67s 1s/step - loss: 0.2651 - acc: 0.9856 - val_loss: 1.7944 - val_acc: 0.7447
#
# Epoch 00090: val_acc did not improve from 0.75232
# Epoch 91/100
# Learning rate:  0.0001
# 58/58 [==============================] - 67s 1s/step - loss: 0.2679 - acc: 0.9837 - val_loss: 1.7756 - val_acc: 0.7474
#
# Epoch 00091: val_acc did not improve from 0.75232
# Epoch 92/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2594 - acc: 0.9862 - val_loss: 1.7885 - val_acc: 0.7551
#
# Epoch 00092: val_acc improved from 0.75232 to 0.75506, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-101_ResNet56v1_model.092.h5
# Epoch 93/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2679 - acc: 0.9844 - val_loss: 1.7934 - val_acc: 0.7507
#
# Epoch 00093: val_acc did not improve from 0.75506
# Epoch 94/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2549 - acc: 0.9878 - val_loss: 1.8051 - val_acc: 0.7490
#
# Epoch 00094: val_acc did not improve from 0.75506
# Epoch 95/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2555 - acc: 0.9867 - val_loss: 1.7956 - val_acc: 0.7490
#
# Epoch 00095: val_acc did not improve from 0.75506
# Epoch 96/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2525 - acc: 0.9885 - val_loss: 1.8118 - val_acc: 0.7501
#
# Epoch 00096: val_acc did not improve from 0.75506
# Epoch 97/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2526 - acc: 0.9881 - val_loss: 1.8026 - val_acc: 0.7518
#
# Epoch 00097: val_acc did not improve from 0.75506
# Epoch 98/100
# Learning rate:  0.0001
# 58/58 [==============================] - 67s 1s/step - loss: 0.2547 - acc: 0.9863 - val_loss: 1.8080 - val_acc: 0.7518
#
# Epoch 00098: val_acc did not improve from 0.75506
# Epoch 99/100
# Learning rate:  0.0001
# 58/58 [==============================] - 66s 1s/step - loss: 0.2525 - acc: 0.9859 - val_loss: 1.8194 - val_acc: 0.7490
#
# Epoch 00099: val_acc did not improve from 0.75506
# Epoch 100/100
# Learning rate:  0.0001
# 58/58 [==============================] - 65s 1s/step - loss: 0.2467 - acc: 0.9870 - val_loss: 1.8421 - val_acc: 0.7496
#
# Epoch 00100: val_acc did not improve from 0.75506

# %%
# score trained model
scores = model.evaluate(x_test,
                        y_test,
                        batch_size=batch_size,
                        verbose=0)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Test loss: 1.8421125411987305
# Test accuracy: 0.7495899200439453
