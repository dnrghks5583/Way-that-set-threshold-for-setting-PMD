# %% [markdown]
# <a href="https://colab.research.google.com/github/dnrghks5583/Way-that-set-threshold-for-setting-PMD/blob/main/CALTECH-101/Continue_ResNet_CALTECH_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from keras.models import load_model
import tensorflow as tf
import os

drive.mount('/content/gdrive')

#load most recent saved model
directory_name = 'CALTECH-101_saved_models_with_lr_e-3'
learning_rate_variable = int(directory_name[-1])
image_size = (128, 128)
path = '/content/gdrive/MyDrive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164'

os.chdir(path)


directory_path = path+'/' + directory_name + '/'
file_name_and_time_lst = []

for saved_models in os.listdir(f"{directory_path}"):
    written_time = os.path.getctime(f"{directory_path}{saved_models}")
    file_name_and_time_lst.append((saved_models, written_time))
 
sorted_file_lst = sorted(file_name_and_time_lst, key=lambda x: x[1], reverse=True)
latest_model = sorted_file_lst[0][0] #originally [0][0]
print('\nLoaded model name : ' , latest_model)

#pickup from the last epoch
initial_epoch = int(latest_model[len(latest_model)-6:-3])

model = tf.keras.models.load_model(directory_path + latest_model)
# Out:
# Mounted at /content/gdrive
#
# Loaded model name :  CALTECH-256_ResNet56v1_model.094.h5

# %%
"""
ResNet v1
[a] Deep Residual Learning for Image Recognition
https://arxiv.org/pdf/1512.03385.pdf
ResNet v2
[b] Identity Mappings in Deep Residual Networks
https://arxiv.org/pdf/1603.05027.pdf

https://github.com/dnrghks5583/Way-that-set-threshold-for-setting-PMD/blob/main/Caltech101/caltech101_resnet.ipynb
"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input
from tensorflow.keras.layers import Flatten, add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import numpy as np
import math

# training parameters
batch_size = 128 # orig paper trained all networks with batch_size=128
epochs = 200
num_classes = 102
data_augmentation = True

# subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 9

# model version
# orig paper: version = 1 (ResNet v1), 
# improved ResNet: version = 2 (ResNet v2)
version = 1

# %%
import gzip
import pickle

os.chdir(path)

with gzip.open('caltech101_x_trainData.pickle', 'rb') as f:
    x_train = pickle.load(f)
    
with gzip.open('caltech101_x_testData.pickle', 'rb') as f:
    x_test = pickle.load(f)
    
with gzip.open('caltech101_y_trainData.pickle', 'rb') as f:
    y_train = pickle.load(f)
    
with gzip.open('caltech101_y_testData.pickle', 'rb') as f:
    y_test = pickle.load(f)

# %%
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# input image dimensions.
input_shape = x_train.shape[1:]

# normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# if subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('Model_Type : ' , model_type)
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# convert class vectors to binary class matrices.
#y_train = to_categorical(y_train, num_classes)
#y_test = to_categorical(y_test, num_classes)
# Out:
# Model_Type :  ResNet56v1
# x_train shape: (7316, 164, 164, 3)
# 7316 train samples
# 1829 test samples
# y_train shape: (7316, 102)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 1*(10**(-learning_rate_variable)) #originally 3
    if epoch > 180:
        lr *= 0.5*(10**(-learning_rate_variable)) #originally 3
    elif epoch > 160:
        lr *= 1*(10**(-learning_rate_variable)) #originally 3
    elif epoch > 120:
        lr *= 1*(10**(-learning_rate_variable+1)) #originally 2
    elif epoch > 80:
        lr *= 1*(10**(-learning_rate_variable+2)) #originally 1
    print('Learning rate: ', lr)
    return lr

# %%
# prepare model model saving directory.

save_dir = os.path.join(os.getcwd(), directory_name)
model_name = 'CALTECH-256_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

# %%
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

#callbacks = [lr_reducer, lr_scheduler]
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # this will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False)
# Out:
# Using real-time data augmentation.

# %%
    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    steps_per_epoch =  math.ceil(len(x_train) / batch_size)
    # fit the model on the batches generated by datagen.flow().
    model.fit(x=datagen.flow(x_train, y_train, batch_size=batch_size),
              initial_epoch = initial_epoch,
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),
              steps_per_epoch=steps_per_epoch,
              callbacks=callbacks)


# score trained model
scores = model.evaluate(x_test,
                        y_test,
                        batch_size=batch_size,
                        verbose=0)

print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Epoch 95/200
# Learning rate:  0.0001
# 58/58 [==============================] - 84s 1s/step - loss: 0.2587 - acc: 0.9852 - val_loss: 1.7761 - val_acc: 0.7518
#
# Epoch 00095: val_acc improved from -inf to 0.75178, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.095.h5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 96/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2582 - acc: 0.9846 - val_loss: 1.7906 - val_acc: 0.7474
#
# Epoch 00096: val_acc did not improve from 0.75178
# Epoch 97/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2553 - acc: 0.9852 - val_loss: 1.8007 - val_acc: 0.7545
#
# Epoch 00097: val_acc improved from 0.75178 to 0.75451, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.097.h5
# Epoch 98/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2508 - acc: 0.9866 - val_loss: 1.8197 - val_acc: 0.7469
#
# Epoch 00098: val_acc did not improve from 0.75451
# Epoch 99/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2479 - acc: 0.9897 - val_loss: 1.8012 - val_acc: 0.7512
#
# Epoch 00099: val_acc did not improve from 0.75451
# Epoch 100/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2491 - acc: 0.9884 - val_loss: 1.7755 - val_acc: 0.7529
#
# Epoch 00100: val_acc did not improve from 0.75451
# Epoch 101/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2500 - acc: 0.9863 - val_loss: 1.8496 - val_acc: 0.7529
#
# Epoch 00101: val_acc did not improve from 0.75451
# Epoch 102/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2460 - acc: 0.9887 - val_loss: 1.8273 - val_acc: 0.7474
#
# Epoch 00102: val_acc did not improve from 0.75451
# Epoch 103/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2427 - acc: 0.9889 - val_loss: 1.8321 - val_acc: 0.7479
#
# Epoch 00103: val_acc did not improve from 0.75451
# Epoch 104/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2457 - acc: 0.9888 - val_loss: 1.8173 - val_acc: 0.7556
#
# Epoch 00104: val_acc improved from 0.75451 to 0.75560, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.104.h5
# Epoch 105/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2427 - acc: 0.9889 - val_loss: 1.8272 - val_acc: 0.7518
#
# Epoch 00105: val_acc did not improve from 0.75560
# Epoch 106/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2442 - acc: 0.9869 - val_loss: 1.8282 - val_acc: 0.7523
#
# Epoch 00106: val_acc did not improve from 0.75560
# Epoch 107/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2423 - acc: 0.9887 - val_loss: 1.7903 - val_acc: 0.7529
#
# Epoch 00107: val_acc did not improve from 0.75560
# Epoch 108/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2365 - acc: 0.9897 - val_loss: 1.8141 - val_acc: 0.7551
#
# Epoch 00108: val_acc did not improve from 0.75560
# Epoch 109/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2365 - acc: 0.9882 - val_loss: 1.8393 - val_acc: 0.7562
#
# Epoch 00109: val_acc improved from 0.75560 to 0.75615, saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_101_164/CALTECH-101_saved_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.109.h5
# Epoch 110/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2399 - acc: 0.9895 - val_loss: 1.8446 - val_acc: 0.7518
#
# Epoch 00110: val_acc did not improve from 0.75615
# Epoch 111/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2331 - acc: 0.9899 - val_loss: 1.8307 - val_acc: 0.7556
#
# Epoch 00111: val_acc did not improve from 0.75615
# Epoch 112/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2315 - acc: 0.9902 - val_loss: 1.8319 - val_acc: 0.7469
#
# Epoch 00112: val_acc did not improve from 0.75615
# Epoch 113/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2322 - acc: 0.9897 - val_loss: 1.8731 - val_acc: 0.7496
#
# Epoch 00113: val_acc did not improve from 0.75615
# Epoch 114/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2289 - acc: 0.9903 - val_loss: 1.9020 - val_acc: 0.7452
#
# Epoch 00114: val_acc did not improve from 0.75615
# Epoch 115/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2369 - acc: 0.9873 - val_loss: 1.8523 - val_acc: 0.7463
#
# Epoch 00115: val_acc did not improve from 0.75615
# Epoch 116/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2289 - acc: 0.9897 - val_loss: 1.8432 - val_acc: 0.7512
#
# Epoch 00116: val_acc did not improve from 0.75615
# Epoch 117/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2290 - acc: 0.9893 - val_loss: 1.8666 - val_acc: 0.7501
#
# Epoch 00117: val_acc did not improve from 0.75615
# Epoch 118/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2275 - acc: 0.9910 - val_loss: 1.8332 - val_acc: 0.7479
#
# Epoch 00118: val_acc did not improve from 0.75615
# Epoch 119/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2225 - acc: 0.9902 - val_loss: 1.8495 - val_acc: 0.7523
#
# Epoch 00119: val_acc did not improve from 0.75615
# Epoch 120/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2224 - acc: 0.9919 - val_loss: 1.8463 - val_acc: 0.7518
#
# Epoch 00120: val_acc did not improve from 0.75615
# Epoch 121/200
# Learning rate:  0.0001
# 58/58 [==============================] - 63s 1s/step - loss: 0.2269 - acc: 0.9889 - val_loss: 1.8686 - val_acc: 0.7474
#
# Epoch 00121: val_acc did not improve from 0.75615
# Epoch 122/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2210 - acc: 0.9913 - val_loss: 1.8686 - val_acc: 0.7518
#
# Epoch 00122: val_acc did not improve from 0.75615
# Epoch 123/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2221 - acc: 0.9926 - val_loss: 1.8614 - val_acc: 0.7501
#
# Epoch 00123: val_acc did not improve from 0.75615
# Epoch 124/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2188 - acc: 0.9923 - val_loss: 1.8592 - val_acc: 0.7501
#
# Epoch 00124: val_acc did not improve from 0.75615
# Epoch 125/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2219 - acc: 0.9911 - val_loss: 1.8549 - val_acc: 0.7501
#
# Epoch 00125: val_acc did not improve from 0.75615
# Epoch 126/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2162 - acc: 0.9938 - val_loss: 1.8523 - val_acc: 0.7501
#
# Epoch 00126: val_acc did not improve from 0.75615
# Epoch 127/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2180 - acc: 0.9923 - val_loss: 1.8516 - val_acc: 0.7512
#
# Epoch 00127: val_acc did not improve from 0.75615
# Epoch 128/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2193 - acc: 0.9936 - val_loss: 1.8480 - val_acc: 0.7518
#
# Epoch 00128: val_acc did not improve from 0.75615
# Epoch 129/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2156 - acc: 0.9941 - val_loss: 1.8539 - val_acc: 0.7512
#
# Epoch 00129: val_acc did not improve from 0.75615
# Epoch 130/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2188 - acc: 0.9926 - val_loss: 1.8652 - val_acc: 0.7501
#
# Epoch 00130: val_acc did not improve from 0.75615
# Epoch 131/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2159 - acc: 0.9937 - val_loss: 1.8609 - val_acc: 0.7496
#
# Epoch 00131: val_acc did not improve from 0.75615
# Epoch 132/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2167 - acc: 0.9934 - val_loss: 1.8599 - val_acc: 0.7501
#
# Epoch 00132: val_acc did not improve from 0.75615
# Epoch 133/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2162 - acc: 0.9936 - val_loss: 1.8567 - val_acc: 0.7507
#
# Epoch 00133: val_acc did not improve from 0.75615
# Epoch 134/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2152 - acc: 0.9928 - val_loss: 1.8546 - val_acc: 0.7501
#
# Epoch 00134: val_acc did not improve from 0.75615
# Epoch 135/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2166 - acc: 0.9922 - val_loss: 1.8571 - val_acc: 0.7507
#
# Epoch 00135: val_acc did not improve from 0.75615
# Epoch 136/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2203 - acc: 0.9925 - val_loss: 1.8547 - val_acc: 0.7501
#
# Epoch 00136: val_acc did not improve from 0.75615
# Epoch 137/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2147 - acc: 0.9940 - val_loss: 1.8584 - val_acc: 0.7501
#
# Epoch 00137: val_acc did not improve from 0.75615
# Epoch 138/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2138 - acc: 0.9938 - val_loss: 1.8614 - val_acc: 0.7479
#
# Epoch 00138: val_acc did not improve from 0.75615
# Epoch 139/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2144 - acc: 0.9938 - val_loss: 1.8550 - val_acc: 0.7490
#
# Epoch 00139: val_acc did not improve from 0.75615
# Epoch 140/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2120 - acc: 0.9949 - val_loss: 1.8573 - val_acc: 0.7469
#
# Epoch 00140: val_acc did not improve from 0.75615
# Epoch 141/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2145 - acc: 0.9941 - val_loss: 1.8556 - val_acc: 0.7501
#
# Epoch 00141: val_acc did not improve from 0.75615
# Epoch 142/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2166 - acc: 0.9926 - val_loss: 1.8568 - val_acc: 0.7490
#
# Epoch 00142: val_acc did not improve from 0.75615
# Epoch 143/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2145 - acc: 0.9934 - val_loss: 1.8600 - val_acc: 0.7469
#
# Epoch 00143: val_acc did not improve from 0.75615
# Epoch 144/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2134 - acc: 0.9940 - val_loss: 1.8662 - val_acc: 0.7469
#
# Epoch 00144: val_acc did not improve from 0.75615
# Epoch 145/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2144 - acc: 0.9943 - val_loss: 1.8695 - val_acc: 0.7458
#
# Epoch 00145: val_acc did not improve from 0.75615
# Epoch 146/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2135 - acc: 0.9940 - val_loss: 1.8651 - val_acc: 0.7463
#
# Epoch 00146: val_acc did not improve from 0.75615
# Epoch 147/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2145 - acc: 0.9923 - val_loss: 1.8642 - val_acc: 0.7458
#
# Epoch 00147: val_acc did not improve from 0.75615
# Epoch 148/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2135 - acc: 0.9933 - val_loss: 1.8566 - val_acc: 0.7458
#
# Epoch 00148: val_acc did not improve from 0.75615
# Epoch 149/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2129 - acc: 0.9940 - val_loss: 1.8631 - val_acc: 0.7436
#
# Epoch 00149: val_acc did not improve from 0.75615
# Epoch 150/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2118 - acc: 0.9948 - val_loss: 1.8544 - val_acc: 0.7474
#
# Epoch 00150: val_acc did not improve from 0.75615
# Epoch 151/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2122 - acc: 0.9949 - val_loss: 1.8500 - val_acc: 0.7485
#
# Epoch 00151: val_acc did not improve from 0.75615
# Epoch 152/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2110 - acc: 0.9945 - val_loss: 1.8549 - val_acc: 0.7469
#
# Epoch 00152: val_acc did not improve from 0.75615
# Epoch 153/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2092 - acc: 0.9941 - val_loss: 1.8458 - val_acc: 0.7485
#
# Epoch 00153: val_acc did not improve from 0.75615
# Epoch 154/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2117 - acc: 0.9937 - val_loss: 1.8496 - val_acc: 0.7496
#
# Epoch 00154: val_acc did not improve from 0.75615
# Epoch 155/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2108 - acc: 0.9951 - val_loss: 1.8528 - val_acc: 0.7496
#
# Epoch 00155: val_acc did not improve from 0.75615
# Epoch 156/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2117 - acc: 0.9943 - val_loss: 1.8616 - val_acc: 0.7518
#
# Epoch 00156: val_acc did not improve from 0.75615
# Epoch 157/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2134 - acc: 0.9923 - val_loss: 1.8516 - val_acc: 0.7512
#
# Epoch 00157: val_acc did not improve from 0.75615
# Epoch 158/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2096 - acc: 0.9959 - val_loss: 1.8527 - val_acc: 0.7523
#
# Epoch 00158: val_acc did not improve from 0.75615
# Epoch 159/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2122 - acc: 0.9941 - val_loss: 1.8403 - val_acc: 0.7534
#
# Epoch 00159: val_acc did not improve from 0.75615
# Epoch 160/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2099 - acc: 0.9945 - val_loss: 1.8512 - val_acc: 0.7545
#
# Epoch 00160: val_acc did not improve from 0.75615
# Epoch 161/200
# Learning rate:  1e-05
# 58/58 [==============================] - 63s 1s/step - loss: 0.2104 - acc: 0.9940 - val_loss: 1.8516 - val_acc: 0.7518
#
# Epoch 00161: val_acc did not improve from 0.75615
# Epoch 162/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2126 - acc: 0.9933 - val_loss: 1.8502 - val_acc: 0.7523
#
# Epoch 00162: val_acc did not improve from 0.75615
# Epoch 163/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2119 - acc: 0.9938 - val_loss: 1.8488 - val_acc: 0.7523
#
# Epoch 00163: val_acc did not improve from 0.75615
# Epoch 164/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2115 - acc: 0.9944 - val_loss: 1.8489 - val_acc: 0.7518
#
# Epoch 00164: val_acc did not improve from 0.75615
# Epoch 165/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2105 - acc: 0.9943 - val_loss: 1.8491 - val_acc: 0.7529
#
# Epoch 00165: val_acc did not improve from 0.75615
# Epoch 166/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2088 - acc: 0.9954 - val_loss: 1.8481 - val_acc: 0.7523
#
# Epoch 00166: val_acc did not improve from 0.75615
# Epoch 167/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2112 - acc: 0.9943 - val_loss: 1.8498 - val_acc: 0.7523
#
# Epoch 00167: val_acc did not improve from 0.75615
# Epoch 168/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2107 - acc: 0.9937 - val_loss: 1.8501 - val_acc: 0.7523
#
# Epoch 00168: val_acc did not improve from 0.75615
# Epoch 169/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2073 - acc: 0.9948 - val_loss: 1.8487 - val_acc: 0.7523
#
# Epoch 00169: val_acc did not improve from 0.75615
# Epoch 170/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2137 - acc: 0.9932 - val_loss: 1.8497 - val_acc: 0.7523
#
# Epoch 00170: val_acc did not improve from 0.75615
# Epoch 171/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2094 - acc: 0.9949 - val_loss: 1.8493 - val_acc: 0.7523
#
# Epoch 00171: val_acc did not improve from 0.75615
# Epoch 172/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2094 - acc: 0.9948 - val_loss: 1.8506 - val_acc: 0.7523
#
# Epoch 00172: val_acc did not improve from 0.75615
# Epoch 173/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2096 - acc: 0.9934 - val_loss: 1.8515 - val_acc: 0.7529
#
# Epoch 00173: val_acc did not improve from 0.75615
# Epoch 174/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2086 - acc: 0.9945 - val_loss: 1.8522 - val_acc: 0.7518
#
# Epoch 00174: val_acc did not improve from 0.75615
# Epoch 175/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2069 - acc: 0.9955 - val_loss: 1.8522 - val_acc: 0.7512
#
# Epoch 00175: val_acc did not improve from 0.75615
# Epoch 176/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2123 - acc: 0.9937 - val_loss: 1.8521 - val_acc: 0.7512
#
# Epoch 00176: val_acc did not improve from 0.75615
# Epoch 177/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2098 - acc: 0.9949 - val_loss: 1.8517 - val_acc: 0.7518
#
# Epoch 00177: val_acc did not improve from 0.75615
# Epoch 178/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2139 - acc: 0.9932 - val_loss: 1.8511 - val_acc: 0.7512
#
# Epoch 00178: val_acc did not improve from 0.75615
# Epoch 179/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2087 - acc: 0.9948 - val_loss: 1.8499 - val_acc: 0.7512
#
# Epoch 00179: val_acc did not improve from 0.75615
# Epoch 180/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2087 - acc: 0.9948 - val_loss: 1.8500 - val_acc: 0.7507
#
# Epoch 00180: val_acc did not improve from 0.75615
# Epoch 181/200
# Learning rate:  1e-06
# 58/58 [==============================] - 63s 1s/step - loss: 0.2085 - acc: 0.9947 - val_loss: 1.8498 - val_acc: 0.7507
#
# Epoch 00181: val_acc did not improve from 0.75615
# Epoch 182/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2087 - acc: 0.9944 - val_loss: 1.8508 - val_acc: 0.7512
#
# Epoch 00182: val_acc did not improve from 0.75615
# Epoch 183/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2083 - acc: 0.9944 - val_loss: 1.8506 - val_acc: 0.7512
#
# Epoch 00183: val_acc did not improve from 0.75615
# Epoch 184/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2062 - acc: 0.9949 - val_loss: 1.8502 - val_acc: 0.7507
#
# Epoch 00184: val_acc did not improve from 0.75615
# Epoch 185/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2104 - acc: 0.9940 - val_loss: 1.8516 - val_acc: 0.7512
#
# Epoch 00185: val_acc did not improve from 0.75615
# Epoch 186/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2122 - acc: 0.9934 - val_loss: 1.8528 - val_acc: 0.7512
#
# Epoch 00186: val_acc did not improve from 0.75615
# Epoch 187/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2077 - acc: 0.9956 - val_loss: 1.8520 - val_acc: 0.7507
#
# Epoch 00187: val_acc did not improve from 0.75615
# Epoch 188/200
# Learning rate:  5e-07
# 58/58 [==============================] - 62s 1s/step - loss: 0.2076 - acc: 0.9958 - val_loss: 1.8520 - val_acc: 0.7501
#
# Epoch 00188: val_acc did not improve from 0.75615
# Epoch 189/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2081 - acc: 0.9947 - val_loss: 1.8522 - val_acc: 0.7507
#
# Epoch 00189: val_acc did not improve from 0.75615
# Epoch 190/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2084 - acc: 0.9943 - val_loss: 1.8527 - val_acc: 0.7518
#
# Epoch 00190: val_acc did not improve from 0.75615
# Epoch 191/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2103 - acc: 0.9937 - val_loss: 1.8523 - val_acc: 0.7523
#
# Epoch 00191: val_acc did not improve from 0.75615
# Epoch 192/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2086 - acc: 0.9944 - val_loss: 1.8528 - val_acc: 0.7523
#
# Epoch 00192: val_acc did not improve from 0.75615
# Epoch 193/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2115 - acc: 0.9944 - val_loss: 1.8525 - val_acc: 0.7523
#
# Epoch 00193: val_acc did not improve from 0.75615
# Epoch 194/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2120 - acc: 0.9944 - val_loss: 1.8518 - val_acc: 0.7518
#
# Epoch 00194: val_acc did not improve from 0.75615
# Epoch 195/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2081 - acc: 0.9951 - val_loss: 1.8523 - val_acc: 0.7512
#
# Epoch 00195: val_acc did not improve from 0.75615
# Epoch 196/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2089 - acc: 0.9941 - val_loss: 1.8511 - val_acc: 0.7512
#
# Epoch 00196: val_acc did not improve from 0.75615
# Epoch 197/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2077 - acc: 0.9951 - val_loss: 1.8492 - val_acc: 0.7512
#
# Epoch 00197: val_acc did not improve from 0.75615
# Epoch 198/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2078 - acc: 0.9949 - val_loss: 1.8503 - val_acc: 0.7512
#
# Epoch 00198: val_acc did not improve from 0.75615
# Epoch 199/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2115 - acc: 0.9933 - val_loss: 1.8517 - val_acc: 0.7507
#
# Epoch 00199: val_acc did not improve from 0.75615
# Epoch 200/200
# Learning rate:  5e-07
# 58/58 [==============================] - 63s 1s/step - loss: 0.2076 - acc: 0.9954 - val_loss: 1.8526 - val_acc: 0.7518
#
# Epoch 00200: val_acc did not improve from 0.75615
# Test loss: 1.8525828123092651
# Test accuracy: 0.751776933670044
